# %%
import pandas as pd
import numpy as np

# %%
def read_data_frame(name):
    return pd.DataFrame.from_csv('../../datasets/matus-home/csv/' + name + '.csv')

labels = read_data_frame('labels')
activity_ids = read_data_frame('activity_ids')

def sensor_tag_accelerometer(sensor_tag_id):
    x = read_data_frame(sensor_tag_id + '_accelerometer_x')
    y = read_data_frame(sensor_tag_id + '_accelerometer_y')
    z = read_data_frame(sensor_tag_id + '_accelerometer_z')
    return [x, y, z]

def sensor_tag_magnetometer(sensor_tag_id):
    x = read_data_frame(sensor_tag_id + '_magnetometer_x')
    y = read_data_frame(sensor_tag_id + '_magnetometer_y')
    z = read_data_frame(sensor_tag_id + '_magnetometer_z')
    return [x, y, z]

def sensor_tag_gyroscope(sensor_tag_id):
    x = read_data_frame(sensor_tag_id + '_gyroscope_x')
    y = read_data_frame(sensor_tag_id + '_gyroscope_y')
    z = read_data_frame(sensor_tag_id + '_gyroscope_z')
    return [x, y, z]

def iphone_accelerometer():
    x = read_data_frame('matus_iphone_accelerometer_x')
    y = read_data_frame('matus_iphone_accelerometer_y')
    z = read_data_frame('matus_iphone_accelerometer_z')
    return [x, y, z]

def iphone_magnetometer():
    x = read_data_frame('matus_iphone_magnetometer_x')
    y = read_data_frame('matus_iphone_magnetometer_y')
    z = read_data_frame('matus_iphone_magnetometer_z')
    return [x, y, z]

def iphone_gravity():
    x = read_data_frame('matus_iphone_gravity_x')
    y = read_data_frame('matus_iphone_gravity_y')
    z = read_data_frame('matus_iphone_gravity_z')
    return [x, y, z]

def mac_microphone():
    return [read_data_frame('matus_mac_microphone')]

def wemo_power():
    return [read_data_frame('221445K12000EF_power')]



sets = []
# sets += sensor_tag_accelerometer('61e7e6b71abe49218f132bad935fcebe')
# sets += sensor_tag_accelerometer('778c5d0e6a744c1c961cdecdb2b29d3c')
# sets += sensor_tag_accelerometer('3a9d6f1b70dd493088305f679f4aa386')
# sets += sensor_tag_accelerometer('f0c688e5fc9e4df4ba87cbd394737884')
# sets += sensor_tag_magnetometer('61e7e6b71abe49218f132bad935fcebe')
# sets += sensor_tag_magnetometer('778c5d0e6a744c1c961cdecdb2b29d3c')
# sets += sensor_tag_magnetometer('3a9d6f1b70dd493088305f679f4aa386')
# sets += sensor_tag_magnetometer('f0c688e5fc9e4df4ba87cbd394737884')
# sets += sensor_tag_gyroscope(sensor_tag_id)
sets += iphone_accelerometer()
# sets += iphone_magnetometer()
# sets += iphone_gravity()
# sets += mac_microphone()
# sets += wemo_power()

df = activity_ids
for s in sets:
    df = df.join(s)

df = df.ffill().bfill()
df
# Out:
#                          id  matus_iphone_accelerometer_x  \
# 2017-02-27 01:27:54.980   1                     -0.001439
# 2017-02-27 01:27:55.000   1                     -0.000265
# 2017-02-27 01:27:55.100   1                     -0.000774
# 2017-02-27 01:27:55.100   1                     -0.000774
# 2017-02-27 01:27:55.120   1                      0.002717
# 2017-02-27 01:27:55.130   1                      0.002717
# 2017-02-27 01:27:55.140   1                     -0.002087
# 2017-02-27 01:27:55.160   1                     -0.000029
# 2017-02-27 01:27:55.180   1                     -0.000430
# 2017-02-27 01:27:55.200   1                      0.000632
# 2017-02-27 01:27:55.200   1                      0.000632
# 2017-02-27 01:27:55.200   1                      0.000632
# 2017-02-27 01:27:55.200   1                      0.000632
# 2017-02-27 01:27:55.200   1                      0.000843
# 2017-02-27 01:27:55.200   1                      0.000843
# ...

# %%
# remove items with a duplicate index
df = df[~df.index.duplicated(keep='first')]
df.index.get_duplicates() # should be empty
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
plot = False

if plot:
    import matplotlib.pyplot as plt
    import matplotlib
    matplotlib.style.use('ggplot')
    fig = plt.figure()

    df.plot.scatter(x='221445K12000EF_power', y='id', color='b', marker="s", label='X')

#     ax = df.plot.scatter(x='778c5d0e6a744c1c961cdecdb2b29d3c_accelerometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='778c5d0e6a744c1c961cdecdb2b29d3c_accelerometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='778c5d0e6a744c1c961cdecdb2b29d3c_accelerometer_z', y='id', color='g', marker="x", label='Z', ax=ax)
    
#     ax = df.plot.scatter(x='3a9d6f1b70dd493088305f679f4aa386_accelerometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='3a9d6f1b70dd493088305f679f4aa386_accelerometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='3a9d6f1b70dd493088305f679f4aa386_accelerometer_z', y='id', color='g', marker="x", label='Z', ax=ax)

#     ax = df.plot.scatter(x='778c5d0e6a744c1c961cdecdb2b29d3c_magnetometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='778c5d0e6a744c1c961cdecdb2b29d3c_magnetometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='778c5d0e6a744c1c961cdecdb2b29d3c_magnetometer_z', y='id', color='g', marker="x", label='Z', ax=ax)
    
#     ax = df.plot.scatter(x='3a9d6f1b70dd493088305f679f4aa386_magnetometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='3a9d6f1b70dd493088305f679f4aa386_magnetometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='3a9d6f1b70dd493088305f679f4aa386_magnetometer_z', y='id', color='g', marker="x", label='Z', ax=ax)

#     ax = df.plot.scatter(x='61e7e6b71abe49218f132bad935fcebe_accelerometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='61e7e6b71abe49218f132bad935fcebe_accelerometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='61e7e6b71abe49218f132bad935fcebe_accelerometer_z', y='id', color='g', marker="x", label='Z', ax=ax)


#     ax = df.plot.scatter(x='f0c688e5fc9e4df4ba87cbd394737884_accelerometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='f0c688e5fc9e4df4ba87cbd394737884_accelerometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='f0c688e5fc9e4df4ba87cbd394737884_accelerometer_z', y='id', color='g', marker="x", label='Z', ax=ax)

#     ax = df.plot.scatter(x='f0c688e5fc9e4df4ba87cbd394737884_magnetometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='f0c688e5fc9e4df4ba87cbd394737884_magnetometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='f0c688e5fc9e4df4ba87cbd394737884_magnetometer_z', y='id', color='g', marker="x", label='Z', ax=ax)


#     ax = df.plot.scatter(x='61e7e6b71abe49218f132bad935fcebe_magnetometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='61e7e6b71abe49218f132bad935fcebe_magnetometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='61e7e6b71abe49218f132bad935fcebe_magnetometer_z', y='id', color='g', marker="x", label='Z', ax=ax)

#     ax = df.plot.scatter(x='matus_mac_microphone', y='id', color='b', marker="s", label='X')


#     ax = df.plot.scatter(x='matus_iphone_accelerometer_x', y='id', color='b', marker="s", label='X')
#     df.plot.scatter(x='matus_iphone_accelerometer_y', y='id', color='r', marker="o", label='Y', ax=ax)
#     df.plot.scatter(x='matus_iphone_accelerometer_z', y='id', color='g', marker="x", label='Z', ax=ax)

    plt.show()

# %%
# split into 5s windows and resample for 100ms sampling rate
windowed_labels = pd.DataFrame(columns=['label'])
new_dfs = []

window_size_secs = 5
i = 0
for id in labels.index:
    label = labels.loc[id]['label']

    activity_df = df[df['id'] == id]
    since = activity_df.index[0]
    until = since + pd.DateOffset(seconds=window_size_secs)

    while len(df[since:until]):
        new_df = df[since:until].copy()
        new_df.id = i

        # resample
        new_df = new_df.resample('100L').ffill().bfill()

        new_dfs.append(new_df)

        since = until
        until = until + pd.DateOffset(seconds=5)

        windowed_labels.loc[i] = [label]
        i += 1

windowed_df = pd.concat(new_dfs)

# %%
#windowed_df.reindex(pd.Series(index=range(len(windowed_df.index)))
windowed_df['new_index'] = pd.Series(range(len(windowed_df.index)), index=windowed_df.index)
windowed_df = windowed_df.set_index(['new_index'])

# %%
# windowed_df

# %%
# training and testing split
indexes = windowed_labels.index.tolist()
np.random.shuffle(indexes)
split = round(0.7*len(indexes))
training_i = indexes[:split]
testing_i = indexes[split:]
df_train = windowed_df.loc[windowed_df.id.isin(training_i)]
df_test = windowed_df.loc[windowed_df.id.isin(testing_i)]

# %%
y_train = windowed_labels.loc[windowed_labels.index.isin(training_i)]
y_test = windowed_labels.loc[windowed_labels.index.isin(testing_i)]

y_train = y_train['label']
y_test = y_test['label']

# %%
X_train = pd.DataFrame(index=y_train.index)
X_test = pd.DataFrame(index=y_test.index)

# %%
from tsfresh.transformers import RelevantFeatureAugmenter, FeatureAugmenter
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.decomposition import PCA

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from pprint import pprint


class ImputeInf(BaseEstimator, TransformerMixin):
    def fit(self, X, y):
        #pprint(X)
        #pprint(y)
        return self

    def transform(self, X):
        #pprint(X)
        #np.set_printoptions(threshold=np.nan)
        X[X == np.inf] = 0.0
        #pprint(np.isfinite(X))
        return X

# %%
# this probably doesn't make sense, find a different
# way to get rid of NaN values
df_train = df_train.ffill()
df_test = df_test.ffill()

# %%
ppl = Pipeline([
#     ('fresh', FeatureAugmenter(column_id='id')),
    ('fresh', RelevantFeatureAugmenter(column_id='id')),
    ('impute', Imputer()),
    ('imput_inf', ImputeInf()),
    #('impute_inf', Imputer(missing_values='inf', strategy='mean', axis=0)),
    ('scale', StandardScaler()),
#     ('pca', PCA()),
    #('standardscaler', StandardScaler(with_mean=True, with_std=True)),
    ('clf', RandomForestClassifier())
])

ppl.set_params(fresh__timeseries_container=df_train)
ppl.fit(X_train, y_train)
# Out:
# Feature Extraction: 100%|██████████| 3/3 [00:16<00:00,  5.59s/it]
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature matus_iphone_accelerometer_x__value_count__value_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature matus_iphone_accelerometer_x__mean_abs_change_quantiles__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature matus_iphone_accelerometer_y__symmetry_looking__r_0.9500000000000001 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature matus_iphone_accelerometer_x__large_standard_deviation__r_0.1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature matus_iphone_accelerometer_y__mean_abs_change_quantiles__qh_0.2__ql_0.8 is constant
# ...

# %%
ppl.set_params(fresh__timeseries_container=df_test)

y_pred = ppl.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
# Feature Extraction: 100%|██████████| 3/3 [00:02<00:00,  1.13it/s]
#              precision    recall  f1-score   support
#
#         0.0       0.86      0.97      0.91        31
#         1.0       0.88      0.78      0.82         9
#         2.0       0.94      0.87      0.91        39
#         3.0       0.92      0.92      0.92        13
#
# avg / total       0.91      0.90      0.90        92
