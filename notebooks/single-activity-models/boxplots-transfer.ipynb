# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

width = 12
height = 7
plt.rcParams["figure.figsize"] = (width, height)


import pandas as pd
import numpy as np
import tflscripts
import json
from sklearn.metrics import accuracy_score

configuration = tflscripts.read_configuration()
df = pd.read_pickle('results.p')

# %%
# filter only transfer within synergy
df = df.loc[df.type_of_transfer != 'No transfer']
df = df.loc[df.source_room == 'synergy']
df = df.loc[df.target_room == 'synergy']

# %%
plt.rcParams["figure.figsize"] = (20, 5)
def classifier_boxplots_for_label(label):
    f, axes = plt.subplots(1, len(df['features'].unique()), sharex=False, sharey=True)
    
    plt.suptitle(label, fontsize="x-large")
#     fig = plt.figure()
#     st = fig.suptitle(label, fontsize="x-large")

    for i, features in enumerate(df['features'].unique()):
        ax = axes[i]
        df_ = df.loc[df.label == label]
        df_ = df_.loc[df_.features == features]
        df_['key'] = df_['source_room'] + '; ' + df_['source_device_name'] + '; ' + df_['features']

        df_ = df_[['classifier', 'accuracy_positive', 'key']]
        df_ = df_.rename(columns={'accuracy_positive': features})
        df_ = pd.pivot_table(df_, values=[features], columns=['classifier'], index=['key'])

        df_.plot.box(ax=ax)
        matplotlib.pyplot.sca(ax)
        plt.xticks(rotation='vertical')
#         ax.title(label + ' ' + features)

    plt.show()

for label in df['label'].unique():
    classifier_boxplots_for_label(label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-edb27cd488f2> in <module>()
#      25
#      26 for label in df['label'].unique():
# ---> 27     classifier_boxplots_for_label(label)
#
# <ipython-input-10-edb27cd488f2> in classifier_boxplots_for_label(label)
#      17         df_ = pd.pivot_table(df_, values=[features], columns=['classifier'], index=['key'])
#      18
# ---> 19         df_.plot.box(ax=ax)
#      20         matplotlib.pyplot.sca(ax)
#      21         plt.xticks(rotation='vertical')
#
# /home/giotto/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in box(self, by, **kwds)
#    2695         axes : matplotlib.AxesSubplot or np.array of them
#    2696         """
# -> 2697         return self(kind='box', by=by, **kwds)
#    2698
#    2699     def hist(self, by=None, bins=10, **kwds):
#
# /home/giotto/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# /home/giotto/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1855                  yerr=yerr, xerr=xerr,
#    1856                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1857                  **kwds)
#    1858
#    1859
#
# /home/giotto/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1680         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1681
# -> 1682     plot_obj.generate()
#    1683     plot_obj.draw()
#    1684     return plot_obj.result
#
# /home/giotto/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in generate(self)
#     234     def generate(self):
#     235         self._args_adjust()
# --> 236         self._compute_plot_data()
#     237         self._setup_subplots()
#     238         self._make_plot()
#
# /home/giotto/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in _compute_plot_data(self)
#     343         if is_empty:
#     344             raise TypeError('Empty {0!r}: no numeric data to '
# --> 345                             'plot'.format(numeric_data.__class__.__name__))
#     346
#     347         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
