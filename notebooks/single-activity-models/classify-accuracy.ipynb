# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

width = 12
height = 7
plt.rcParams["figure.figsize"] = (width, height)


from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import tflscripts
import json
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from sklearn import tree
import pickle

configuration = tflscripts.read_configuration()
df = pd.read_pickle('results.p')

# %%
without_transfer = df.loc[df.type_of_transfer == 'No transfer']

def apply_accuracy_without_transfer(x):
    queried = without_transfer.query('source_device_name == "{}" & source_dataset == "{}" & features == "{}" & label == "{}" & classifier == "{}"'.format(
        x['source_device_name'],
        x['source_dataset'],
        x['features'],
        x['label'],
        x['classifier']
    ))

    if len(queried) > 0:
        return queried['accuracy_positive'].iloc[0]

    return -1

def apply_accuracy_without_transfer_dishes(x):
    return apply_accuracy_without_transfer_for_label(x, x['label'])

def to_accuracy_bin(acc):
    bins = [
        [0.0, 0.75],
        [0.75, 1.0]
    ]
    return [i for i, b in enumerate(bins) if b[0] <= acc and b[1] >= acc][0]


df['accuracy_bin'] = [to_accuracy_bin(a) for a in df['accuracy_positive']]
df['accuracy_without_transfer'] = df.apply(apply_accuracy_without_transfer, axis=1)

# %%
accuracies = {}

test_split = 0.33
# filtered = df.loc[df.accuracy_negative >= 0.95]
filtered = df
filtered = filtered.loc[filtered.type_of_transfer != 'No transfer']
filtered = filtered.loc[filtered.type_of_transfer != 'Across spaces']

msk = np.random.rand(len(filtered)) <= test_split
train = filtered[msk]
test = filtered[~msk]

x_columns = [
    'features',
    'classifier',
    'label',
    'type_of_transfer',
    'accuracy_without_transfer',
    'accuracy_negative'
]

def to_x_and_y(filtered):

    X = filtered[x_columns]

    y = filtered['accuracy_bin']

    X = [dict(r.iteritems()) for _, r in X.iterrows()]
    y = y.values

    return X, y

X_train, y_train = to_x_and_y(train)
X_test, y_test = to_x_and_y(test)

ppl = Pipeline([
    ('vect', DictVectorizer()),
    ('impute', Imputer()),
    ('clf', RandomForestClassifier())
])

ppl.fit(X_train, y_train)
predicted = ppl.predict(X_test)
accuracy = accuracy_score(y_test, predicted)
print(accuracy)
# Out:
# 0.904930966469

# %%
predictions = pd.Series(predicted)
predictions.index = test.index
df['predictions'] = predictions

df_tested = df.loc[df.predictions >= 0]
counts = df_tested[['accuracy_bin', 'predictions']].groupby(['accuracy_bin', 'predictions']).size()
counts = pd.DataFrame(counts)
counts.columns = ['count']
counts.pivot_table(index=['accuracy_bin'], columns=['predictions'], values=['count'])
# Out:
#              count
# predictions    0.0  1.0
# accuracy_bin
# 0             6542  197
# 1              526  340

# %%
df_tested.to_pickle('results_with_accuracy_classified.p')

# %%
df_tested
# Out:
#             source_dataset       target_dataset    source_device  \
# 1      synergy-final-iter4  synergy-final-iter1  128.237.247.190
# 3      synergy-final-iter4  synergy-final-iter2  128.237.247.190
# 5      synergy-final-iter4  synergy-final-iter4  128.237.247.190
# 6      synergy-final-iter4  synergy-final-iter5  128.237.247.190
# 7      synergy-final-iter4  synergy-final-iter5  128.237.247.190
# 14     synergy-final-iter4  synergy-final-iter1  128.237.247.190
# 16     synergy-final-iter4  synergy-final-iter2  128.237.247.190
# 17     synergy-final-iter4  synergy-final-iter4  128.237.247.190
# 19     synergy-final-iter4  synergy-final-iter5  128.237.247.190
#
# 24620  128.237.246.127      Mite 3 Coffee       Mite 1 Table     synergy
# 24621   128.237.227.76      Mite 3 Coffee        Mite 2 Sink     synergy
# 24622  128.237.247.190      Mite 3 Coffee       Mite 1 Table     synergy
# 24625  128.237.246.127      Mite 3 Coffee      Mite 1 Coffee     synergy
# 24626  128.237.246.127      Mite 3 Coffee       Mite 1 Table     synergy
# 24627   128.237.227.76      Mite 3 Coffee        Mite 2 Sink     synergy
# 24628  128.237.247.190      Mite 3 Coffee       Mite 1 Table     synergy
# 24631  128.237.246.127      Mite 3 Coffee      Mite 1 Coffee     synergy
# 24637  128.237.246.127      Mite 3 Coffee      Mite 1 Coffee     synergy
# 24638  128.237.246.127      Mite 3 Coffee       Mite 1 Table     synergy
# 24640  128.237.247.190      Mite 3 Coffee       Mite 1 Table     synergy
# 24643  128.237.246.127      Mite 3 Coffee      Mite 1 Coffee     synergy
# 24644  128.237.246.127      Mite 3 Coffee       Mite 1 Table     synergy
# 24646  128.237.247.190      Mite 3 Coffee       Mite 1 Table     synergy
# 24650  128.237.254.195      Mite 3 Coffee        Mite 3 Sink     synergy
# 24651  128.237.246.127      Mite 3 Coffee      Mite 1 Coffee     synergy
# 24653  128.237.248.186      Mite 3 Coffee        Mite 2 Sink     synergy
# 24655  128.237.247.190      Mite 3 Coffee       Mite 1 Table     synergy
# 24657  128.237.250.218      Mite 3 Coffee      Mite 4 Coffee     synergy
# 24658  128.237.247.190      Mite 3 Coffee       Mite 1 Table     synergy
#
#       target_room source_placement target_placement     ...       \
# 1         synergy            Table             Sink     ...
# 3         synergy            Table             Sink     ...
# 5         synergy            Table           Coffee     ...
# 6         synergy            Table           Coffee     ...
# 7         synergy            Table             Sink     ...
# 14        synergy            Table            Table     ...
# 16        synergy            Table           Coffee     ...
# 17        synergy            Table           Coffee     ...
# 19        synergy            Table             Sink     ...
# 25        synergy            Table             Sink     ...
# 26        synergy            Table            Table     ...
# 27        synergy            Table             Sink     ...
# 28        synergy            Table           Coffee     ...
# 29        synergy            Table           Coffee     ...
# 30        synergy            Table           Coffee     ...
# 31        synergy            Table             Sink     ...
# 37        synergy            Table             Sink     ...
# 39        synergy            Table             Sink     ...
# 41        synergy            Table           Coffee     ...
# 49        synergy            Table             Sink     ...
# 52        synergy            Table           Coffee     ...
# 53        synergy            Table           Coffee     ...
# 54        synergy            Table           Coffee     ...
# 55        synergy            Table             Sink     ...
# 61        synergy            Table             Sink     ...
# 64        synergy            Table           Coffee     ...
# 66        synergy            Table           Coffee     ...
# 67        synergy            Table             Sink     ...
# 73        synergy            Table             Sink     ...
# 74        synergy            Table            Table     ...
# ...           ...              ...              ...     ...
# 24589     synergy           Coffee           Coffee     ...
# 24593     synergy           Coffee           Coffee     ...
# 24597     synergy           Coffee           Coffee     ...
# 24598     synergy           Coffee            Table     ...
# 24602     synergy           Coffee            Table     ...
# 24605     synergy           Coffee           Coffee     ...
# 24606     synergy           Coffee            Table     ...
# 24610     synergy           Coffee            Table     ...
# 24613     synergy           Coffee           Coffee     ...
# 24616     synergy           Coffee            Table     ...
# 24620     synergy           Coffee            Table     ...
# 24621     synergy           Coffee             Sink     ...
# 24622     synergy           Coffee            Table     ...
# 24625     synergy           Coffee           Coffee     ...
# 24626     synergy           Coffee            Table     ...
# 24627     synergy           Coffee             Sink     ...
# 24628     synergy           Coffee            Table     ...
# 24631     synergy           Coffee           Coffee     ...
# 24637     synergy           Coffee           Coffee     ...
# 24638     synergy           Coffee            Table     ...
# 24640     synergy           Coffee            Table     ...
# 24643     synergy           Coffee           Coffee     ...
# 24644     synergy           Coffee            Table     ...
# 24646     synergy           Coffee            Table     ...
# 24650     synergy           Coffee             Sink     ...
# 24651     synergy           Coffee           Coffee     ...
# 24653     synergy           Coffee             Sink     ...
# 24655     synergy           Coffee            Table     ...
# 24657     synergy           Coffee           Coffee     ...
# 24658     synergy           Coffee            Table     ...
#
#                    classifier                   label  \
# 1                         SVM                  Kettle
# 3                         SVM                  Kettle
# 5                         SVM                  Kettle
# 6                         SVM                  Kettle
# 7                         SVM                  Kettle
# 14     RandomForestClassifier                  Kettle
# 16     RandomForestClassifier                  Kettle
# 17     RandomForestClassifier                  Kettle
# 19     RandomForestClassifier                  Kettle
# 25         LogisticRegression                  Kettle
# 26         LogisticRegression                  Kettle
# 27         LogisticRegression                  Kettle
# 28         LogisticRegression                  Kettle
# 29         LogisticRegression                  Kettle
# 30         LogisticRegression                  Kettle
# 31         LogisticRegression                  Kettle
# 37                        SVM                  Kettle
# 39                        SVM                  Kettle
# 41                        SVM                  Kettle
# 49     RandomForestClassifier                  Kettle
# 52     RandomForestClassifier                  Kettle
# 53     RandomForestClassifier                  Kettle
# 54     RandomForestClassifier                  Kettle
# 55     RandomForestClassifier                  Kettle
# 61         LogisticRegression                  Kettle
# 64         LogisticRegression                  Kettle
# 66         LogisticRegression                  Kettle
# 67         LogisticRegression                  Kettle
# 73                        SVM                  Kettle
# 74                        SVM                  Kettle
# ...                       ...                     ...
# 24589                     SVM  Microwave button press
# 24593  RandomForestClassifier  Microwave button press
# 24597      LogisticRegression  Microwave button press
# 24598      LogisticRegression  Microwave button press
# 24602                     SVM  Microwave button press
# 24605  RandomForestClassifier  Microwave button press
# 24606  RandomForestClassifier  Microwave button press
# 24610      LogisticRegression  Microwave button press
# 24613                     SVM                Knocking
# 24616                     SVM                Knocking
# 24620  RandomForestClassifier                Knocking
# 24621  RandomForestClassifier                Knocking
# 24622  RandomForestClassifier                Knocking
# 24625      LogisticRegression                Knocking
# 24626      LogisticRegression                Knocking
# 24627      LogisticRegression                Knocking
# 24628      LogisticRegression                Knocking
# 24631                     SVM                Knocking
# 24637  RandomForestClassifier                Knocking
# 24638  RandomForestClassifier                Knocking
# 24640  RandomForestClassifier                Knocking
# 24643      LogisticRegression                Knocking
# 24644      LogisticRegression                Knocking
# 24646      LogisticRegression                Knocking
# 24650                     SVM                Knocking
# 24651                     SVM                Knocking
# 24653                     SVM                Knocking
# 24655                     SVM                Knocking
# 24657                     SVM                Knocking
# 24658                     SVM                Knocking
#
#                                   features                 features_name  \
# 1                                       .*                           All
# 3                                       .*                           All
# 5                                       .*                           All
# 6                                       .*                           All
# 7                                       .*                           All
# 14                                      .*                           All
# 16                                      .*                           All
# 17                                      .*                           All
# 19                                      .*                           All
# 25                                      .*                           All
# 26                                      .*                           All
# 27                                      .*                           All
# 28                                      .*                           All
# 29                                      .*                           All
# 30                                      .*                           All
# 31                                      .*                           All
# 37                  MICROPHONE_|microphone                    Microphone
# 39                  MICROPHONE_|microphone                    Microphone
# 41                  MICROPHONE_|microphone                    Microphone
# 49                  MICROPHONE_|microphone                    Microphone
# 52                  MICROPHONE_|microphone                    Microphone
# 53                  MICROPHONE_|microphone                    Microphone
# 54                  MICROPHONE_|microphone                    Microphone
# 55                  MICROPHONE_|microphone                    Microphone
# 61                  MICROPHONE_|microphone                    Microphone
# 64                  MICROPHONE_|microphone                    Microphone
# 66                  MICROPHONE_|microphone                    Microphone
# 67                  MICROPHONE_|microphone                    Microphone
# 73           temperature|pressure|humidity                 Environmental
# 74           temperature|pressure|humidity                 Environmental
# ...                                    ...                           ...
# 24589                         EMI|IRMOTION                  EMI & motion
# 24593                         EMI|IRMOTION                  EMI & motion
# 24597                         EMI|IRMOTION                  EMI & motion
# 24598                         EMI|IRMOTION                  EMI & motion
# 24602  MICROPHONE|microphone|ACCEL_|accel_    Microphone & accelerometer
# 24605  MICROPHONE|microphone|ACCEL_|accel_    Microphone & accelerometer
# 24606  MICROPHONE|microphone|ACCEL_|accel_    Microphone & accelerometer
# 24610  MICROPHONE|microphone|ACCEL_|accel_    Microphone & accelerometer
# 24613                                   .*                           All
# 24616                                   .*                           All
# 24620                                   .*                           All
# 24621                                   .*                           All
# 24622                                   .*                           All
# 24625                                   .*                           All
# 24626                                   .*                           All
# 24627                                   .*                           All
# 24628                                   .*                           All
# 24631               MICROPHONE_|microphone                    Microphone
# 24637               MICROPHONE_|microphone                    Microphone
# 24638               MICROPHONE_|microphone                    Microphone
# 24640               MICROPHONE_|microphone                    Microphone
# 24643               MICROPHONE_|microphone                    Microphone
# 24644               MICROPHONE_|microphone                    Microphone
# 24646               MICROPHONE_|microphone                    Microphone
# 24650                   ACCEL_|accel_|mag_  Accelerometer & magnetometer
# 24651                   ACCEL_|accel_|mag_  Accelerometer & magnetometer
# 24653                   ACCEL_|accel_|mag_  Accelerometer & magnetometer
# 24655                   ACCEL_|accel_|mag_  Accelerometer & magnetometer
# 24657                   ACCEL_|accel_|mag_  Accelerometer & magnetometer
# 24658                   ACCEL_|accel_|mag_  Accelerometer & magnetometer
#
#        accuracy  accuracy_positive  accuracy_negative  accuracy_bin  \
# 1      0.755102           0.324251           0.832842             0
# 3      0.795918           0.469169           0.849538             0
# 5      0.771228           0.730769           0.776916             0
# 6      0.657570           0.845946           0.635166             1
# 7      0.691145           0.756757           0.682885             1
# 53                      0.188889          0.0
# 54                      0.188889          0.0
# 55                      0.188889          0.0
# 61                      0.419355          0.0
# 64                      0.419355          0.0
# 66                      0.419355          0.0
# 67                      0.419355          0.0
# 73                      0.111111          0.0
# 74                      0.111111          0.0
# ...                          ...          ...
# 24589                   0.000000          0.0
# 24593                   0.571429          0.0
# 24597                   0.000000          0.0
# 24598                   0.000000          0.0
# 24602                   0.800000          1.0
# 24605                   0.333333          0.0
# 24606                   0.333333          0.0
# 24610                   0.833333          0.0
# 24613                   1.000000          0.0
# 24616                   1.000000          0.0
# 24620                   0.500000          0.0
# 24621                   0.500000          0.0
# 24622                   0.500000          0.0
# 24625                   1.000000          0.0
# 24626                   1.000000          0.0
# 24627                   1.000000          0.0
# 24628                   1.000000          0.0
# 24631                   1.000000          0.0
# 24637                   0.333333          0.0
# 24638                   0.333333          0.0
# 24640                   0.333333          0.0
# 24643                   0.500000          0.0
# 24644                   0.500000          0.0
# 24646                   0.500000          0.0
# 24650                   0.333333          0.0
# 24651                   0.333333          0.0
# 24653                   0.333333          0.0
# 24655                   0.333333          0.0
# 24657                   0.333333          0.0
# 24658                   0.333333          0.0
#
# [7605 rows x 21 columns]

# %%
import pickle

class TransferableModelsForCase:
    def __init__(self, target_device_name, target_dataset):
        self.target_device_name = target_device_name
        self.target_dataset = target_dataset
        self.transferable_models = []
        
    def add_transferable_model(self, source_dataset, source_device_name, label,
                               classifier, features,
                               accuracy_positive, accuracy_negative):
        self.transferable_models.append({
            "source_dataset": source_dataset,
            "source_device_name": source_device_name,
            "label": label,
            "classifier": classifier,
            "features": features,
            "accuracy_positive": accuracy_positive,
            "accuracy_negative": accuracy_negative
        })

transferable_models = []
for _, case in cases.iterrows():
    device_name = case['target_device_name']
    dataset = case['target_dataset']
    
    models_for_case = TransferableModelsForCase(target_device_name=device_name,
                                               target_dataset=dataset)
    
    print(dataset, device_name)
    df_relevant = df_tested.loc[df_tested.target_device_name == device_name]
    df_relevant = df_relevant.loc[df_relevant.target_dataset == dataset]

    predicted_models = df_relevant.loc[df_relevant.predictions == 2]
    for i, row in predicted_models.iterrows():
        models_for_case.add_transferable_model(source_dataset=row['source_dataset'],
                                               source_device_name=row['source_device_name'],
                                               classifier=row['classifier'],
                                               label=row['label'],
                                               features=row['features'],
                                               accuracy_positive=row['accuracy_positive'],
                                               accuracy_negative=row['accuracy_negative'])
    transferable_models.append(models_for_case)

output = open('transferable_models.p', 'wb')
pickle.dump(transferable_models, output)
output.close()
# Out:
# synergy-final-iter1 Mite 3 Sink
# synergy-final-iter2 Mite 3 Coffee
# synergy-final-iter5 Mite 4 Sink
# synergy-final-iter1 Mite 2 Table
# synergy-final-iter4 Mite 1 Table
# synergy-final-iter4 Mite 4 Coffee
# synergy-final-iter5 Mite 2 Coffee
# synergy-final-iter2 Mite 2 Sink
# robotics-final Mite 1 Coffee
# robotics-final Mite 4 Sink
# scott-final-iter1 Mite 4 Right
# scott-final-iter1 Mite 2 Left
