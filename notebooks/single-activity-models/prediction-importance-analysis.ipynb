# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

width = 12
height = 7
plt.rcParams["figure.figsize"] = (width, height)

import pandas as pd
import numpy as np
import tflscripts
import json
import pickle

configuration = tflscripts.read_configuration()
df = pd.read_pickle('results_filtered.p')

# %%
without_transfer = df.loc[df.type_of_transfer == 'No transfer']
df_transfer = df.loc[df.type_of_transfer != 'No transfer']

def apply_accuracy_without_transfer(x):
    queried = without_transfer.query('source_device_name == "{}" & source_dataset == "{}" & features == "{}" & label == "{}" & classifier == "{}"'.format(
        x['source_device_name'],
        x['source_dataset'],
        x['features'],
        x['label'],
        x['classifier']
    ))

    if len(queried) > 0:
        return queried['accuracy'].iloc[0], \
            queried['accuracy_positive'].iloc[0], \
            queried['accuracy_negative'].iloc[0],

    return -1

df_transfer['accuracy_wt'], df_transfer['accuracy_positive_wt'], df_transfer['accuracy_negative_wt'] = \
zip(*df_transfer.apply(apply_accuracy_without_transfer, axis=1))
# Out:
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def device_name(name):
    return ' '.join(name.split(' ')[0:2])


df_transfer['devices'] = [device_name(row['source_device_name']) + '->' + device_name(row['target_device_name']) for i, row in df_transfer.iterrows()]
df_transfer['target_device'] = [device_name(row['target_device_name']) for i, row in df_transfer.iterrows()]
df_transfer['source_device'] = [device_name(row['source_device_name']) for i, row in df_transfer.iterrows()]
df_transfer['replica'] = ['Replica' if row['source_device'] == row['target_device'] else 'Not replica' for i, row in df_transfer.iterrows()]
df_transfer['samples_r'] = np.round(df_transfer.samples.values / 10) * 10
# Out:
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_transfer['accuracy_change'] = df_transfer['accuracy'] - df_transfer['accuracy_wt']
df_transfer['accuracy_positive_change'] = df_transfer['accuracy_positive'] - df_transfer['accuracy_positive_wt']
df_transfer['accuracy_negative_change'] = df_transfer['accuracy_negative'] - df_transfer['accuracy_negative_wt']
# Out:
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/giotto/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import seaborn as sns

def plot_by(column, label='Microwave', features='Microphone', classifier='LogisticRegression',
            x_value_column='accuracy_negative', y_value_column='accuracy_negative_wt', common_limits=True):

    df_plot = df_transfer
    if label is not None:
        df_plot = df_plot.loc[df_plot.label == label]
    df_plot = df_plot.loc[df_plot.features_name == features]
    df_plot = df_plot.loc[df_plot.classifier == classifier]

    fig, ax = plt.subplots()

    for value in df_plot[column].drop_duplicates():
        subdf_plot = df_plot.loc[df_plot[column] == value]
        if len(subdf_plot) > 0:
            ax.scatter(subdf_plot[x_value_column], subdf_plot[y_value_column], label=value)
    ax.legend()

    min_val = min(df_plot[x_value_column].min(), df_plot[y_value_column].min()) - 0.02
    max_val = max(df_plot[x_value_column].max(), df_plot[y_value_column].max()) + 0.02

    if common_limits:
        ax.set_ylim(min_val, max_val)
        ax.set_xlim(min_val, max_val)

    plt.title(column)
    plt.xlabel(x_value_column)
    plt.ylabel(y_value_column)
    plt.show()


def boxplot_by(column, label='Microwave', features='Microphone', classifier='LogisticRegression',
            value_column='accuracy_positive_change'):
    df_plot = df_transfer
    if label is not None:
        df_plot = df_plot.loc[df_plot.label == label]
    df_plot = df_plot.loc[df_plot.features_name == features]
    df_plot = df_plot.loc[df_plot.classifier == classifier]

    newdf = pd.DataFrame()

    for device in df_plot[column].unique():
        subdf = df_plot.loc[df_plot[column] == device]
        newdf[device] = subdf[value_column].reset_index(drop=True)

    newdf = newdf.sort_index(axis=1)
    newdf.plot.box()
    plt.title(column)
    plt.xticks(rotation='vertical')
    plt.show()

def heatmap_by(x_column, y_column, value_column,
               label=None, features='Microphone', classifier='LogisticRegression',
               common_limits=True):

    title_parts = []
    
    df_plot = df_transfer
    if label is not None:
        df_plot = df_plot.loc[df_plot.label == label]
        title_parts.append(label)
    if features is not None:
        df_plot = df_plot.loc[df_plot.features_name == features]
        title_parts.append(features)
    if classifier is not None:
        df_plot = df_plot.loc[df_plot.classifier == classifier]
        title_parts.append(classifier)
        

    df_plot = df_plot.groupby([x_column, y_column])[value_column].mean()
    df_plot = df_plot.reset_index()
    df_plot = df_plot.pivot(index=y_column, columns=x_column, values=value_column)
    sns.heatmap(df_plot, annot=True)
    plt.title(', '.join(title_parts))
    plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import accuracy_score

label = 'Microwave'
features = 'All'
value_column = 'accuracy_positive_change'

df_plot = df_transfer
df_plot = df_plot.loc[df_plot.label == label]
df_plot = df_plot.loc[df_plot.features_name == features]
df_plot = df_plot.loc[df_plot.classifier == 'LogisticRegression']
df_plot['y'] = np.round(df_plot[value_column] * 10)
X_columns = [
    'source_dataset', 'target_dataset',
    'source_device', 'target_device',
    'type_of_transfer',
    'source_room', 'target_room',
    'source_placement', 'target_placement',
#     'accuracy_wt', 'accuracy_positive_wt', 'accuracy_negative_wt',
    'replica', 'samples'
]
X = df_plot[X_columns]
vect = DictVectorizer()

X = [dict(r.iteritems()) for _, r in X.iterrows()]
X = vect.fit_transform(X)
X = pd.DataFrame(X.toarray())
X.columns = vect.feature_names_

all_importances = []
accuracies = []

for i in range(50):
    rf = RandomForestClassifier()
    rf.fit(X.values, df_plot['y'].values)
    importances = pd.Series(rf.feature_importances_)
    all_importances.append(importances)
    accuracies.append(accuracy_score(df_plot['y'].values, rf.predict(X.values)))

importances = pd.DataFrame(all_importances).mean()
importances.index = X.columns
importances = importances.sort_values(ascending=False)
importances.plot.bar()
plt.title(label)
print(np.mean(accuracies))
# Out:
# 0.978787878788

# %%
from sklearn.svm import SVC

all_coefficients = None
num_coefficients = 0
for i in range(10):
    clf = SVC(kernel='linear')
    clf.fit(X.values, df_plot['y'].values)
    if all_coefficients is None:
        all_coefficients = clf.coef_.copy()
    else:
        all_coefficients += clf.coef_.copy()
    num_coefficients += 1
    accuracies.append(accuracy_score(df_plot['y'].values, clf.predict(X.values)))

all_coefficients = all_coefficients / num_coefficients

weights = pd.DataFrame(all_coefficients)
weights.columns = X.columns
# weights.index = np.sort(df_plot['y'].unique())
plt.pcolor(weights)
plt.yticks(np.arange(0.5, len(weights.index), 1), weights.index)
plt.xticks(np.arange(0.5, len(weights.columns), 1), weights.columns, rotation='vertical')
plt.colorbar()
plt.title(label)
print(np.mean(accuracies))
plt.show()
weights.mean().sort_values(ascending=False).plot.bar()
# Out:
# 0.95202020202

# %%
df_plot = df_transfer
df_plot = df_plot.loc[df_plot.label == 'Dishes']
df_plot = df_plot.loc[df_plot.features_name == 'Microphone']
df_plot = df_plot.loc[df_plot.classifier == 'SVM']
df_plot = df_plot[['samples', 'accuracy_change']]
df_plot.groupby(['samples'])['accuracy_change'].mean().plot()

# %%
plt.rcParams["figure.figsize"] = (7, 7)

features = 'All'
label = 'Dishes'
value_column = 'accuracy_change'

boxplot_by('target_dataset', value_column=value_column, label=label, features=features)
boxplot_by('source_placement', value_column=value_column, label=label, features=features)
boxplot_by('target_placement', value_column=value_column, label=label, features=features)
boxplot_by('source_device', value_column=value_column, label=label, features=features)
boxplot_by('target_device', value_column=value_column, label=label, features=features)
boxplot_by('devices', value_column=value_column, label=label, features=features)
boxplot_by('source_dataset', value_column=value_column, label=label, features=features)
boxplot_by('target_dataset', value_column=value_column, label=label, features=features)
boxplot_by('type_of_transfer', value_column=value_column, label=label, features=features)
boxplot_by('replica', value_column=value_column, label=label, features=features)
boxplot_by('samples', value_column=value_column, label=label, features=features)
boxplot_by('label', value_column=value_column, label=None, features=features)

# %%
x_value_column = 'accuracy_positive_wt'
y_value_column = 'accuracy_positive_change'
label='Knocking'
features='Microphone'

plot_by('source_dataset', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('target_dataset', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('source_room', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('target_room', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('source_placement', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('target_placement', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('source_device', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('target_device', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('devices', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('replica', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('type_of_transfer', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('label', x_value_column=x_value_column, y_value_column=y_value_column, common_limits=False, label=label, features=features)
plot_by('samples_r', x_value_column='samples', y_value_column=y_value_column, common_limits=False, label=label, features=features)

# %%
value_column = 'accuracy_positive'
heatmap_by('label', 'type_of_transfer', value_column, label=None, features='All', classifier='LogisticRegression')
heatmap_by('label', 'target_dataset', value_column, label=None, features='All', classifier='LogisticRegression')
heatmap_by('label', 'source_dataset', value_column, label=None, features='All', classifier='LogisticRegression')
heatmap_by('label', 'classifier', value_column, label=None, features='All', classifier=None)
heatmap_by('label', 'features_name', value_column, label=None, features=None, classifier='LogisticRegression')
heatmap_by('target_dataset', 'source_dataset', value_column, label='Dishes', features='All', classifier='LogisticRegression')
heatmap_by('target_dataset', 'source_dataset', value_column, label='Dishes', features='Microphone', classifier='LogisticRegression')
heatmap_by('target_dataset', 'source_dataset', value_column, label='Chopping food', features='All', classifier='LogisticRegression')
heatmap_by('target_dataset', 'source_dataset', value_column, label='Chopping food', features='Microphone', classifier='LogisticRegression')
heatmap_by('features_name', 'classifier', value_column, label=None, features=None, classifier=None)

# %%
df_transfer
# Out:
#           source_dataset       target_dataset source_device target_device  \
# 1      scott-final-iter1  synergy-final-iter1        Mite 4        Mite 3
# 2      scott-final-iter1  synergy-final-iter1        Mite 4        Mite 2
# 3      scott-final-iter1  synergy-final-iter2        Mite 4        Mite 2
# 4      scott-final-iter1  synergy-final-iter2        Mite 4        Mite 3
# 5      scott-final-iter1  synergy-final-iter4        Mite 4        Mite 1
# 6      scott-final-iter1  synergy-final-iter4        Mite 4        Mite 4
# 7      scott-final-iter1  synergy-final-iter5        Mite 4        Mite 2
# 8      scott-final-iter1  synergy-final-iter5        Mite 4        Mite 4
# 9      scott-final-iter1    scott-final-iter1        Mite 4        Mite 2
# 10     scott-final-iter1       robotics-final        Mite 4        Mite 1
# 11     scott-final-iter1       robotics-final        Mite 4        Mite 4
# 13     scott-final-iter1  synergy-final-iter1        Mite 4        Mite 3
# 14     scott-final-iter1  synergy-final-iter1        Mite 4        Mite 2
# 15     scott-final-iter1  synergy-final-iter2        Mite 4        Mite 2
# 16     scott-final-iter1  synergy-final-iter2        Mite 4        Mite 3
# 17     scott-final-iter1  synergy-final-iter4        Mite 4        Mite 1
# 18     scott-final-iter1  synergy-final-iter4        Mite 4        Mite 4
# 19     scott-final-iter1  synergy-final-iter5        Mite 4        Mite 2
# 20     scott-final-iter1  synergy-final-iter5        Mite 4        Mite 4
# 21     scott-final-iter1    scott-final-iter1        Mite 4        Mite 2
# 22     scott-final-iter1       robotics-final        Mite 4        Mite 1
# 23     scott-final-iter1       robotics-final        Mite 4        Mite 4
# 25     scott-final-iter1  synergy-final-iter1        Mite 4        Mite 3
# 26     scott-final-iter1  synergy-final-iter1        Mite 4        Mite 2
# 27     scott-final-iter1  synergy-final-iter2        Mite 4        Mite 2
# 28     scott-final-iter1  synergy-final-iter2        Mite 4        Mite 3
# 29     scott-final-iter1  synergy-final-iter4        Mite 4        Mite 1
# 30     scott-final-iter1  synergy-final-iter4        Mite 4        Mite 4
# 31     scott-final-iter1  synergy-final-iter5        Mite 4        Mite 2
# 32     scott-final-iter1  synergy-final-iter5        Mite 4        Mite 4
# ...                  ...                  ...           ...           ...
# 63047     robotics-final       robotics-final        Mite 2        Mite 4
# 63048     robotics-final       robotics-final        Mite 2        Mite 4
# 63049     robotics-final       robotics-final        Mite 2        Mite 4
# 63050     robotics-final       robotics-final        Mite 2        Mite 4
# 63051     robotics-final       robotics-final        Mite 2        Mite 4
# 63052     robotics-final       robotics-final        Mite 2        Mite 4
# 63053     robotics-final       robotics-final        Mite 2        Mite 4
# 63054     robotics-final       robotics-final        Mite 2        Mite 4
# 63055     robotics-final       robotics-final        Mite 2        Mite 4
# 63056     robotics-final       robotics-final        Mite 2        Mite 4
# 63057     robotics-final       robotics-final        Mite 2        Mite 4
# 63058     robotics-final       robotics-final        Mite 2        Mite 4
# 63059     robotics-final       robotics-final        Mite 2        Mite 4
# 63060     robotics-final       robotics-final        Mite 2        Mite 4
# 63061     robotics-final       robotics-final        Mite 2        Mite 4
# 63062     robotics-final       robotics-final        Mite 2        Mite 4
# 63063     robotics-final       robotics-final        Mite 2        Mite 4
# 63064     robotics-final       robotics-final        Mite 2        Mite 4
# 63065     robotics-final       robotics-final        Mite 2        Mite 4
# 63066     robotics-final       robotics-final        Mite 2        Mite 4
# 63067     robotics-final       robotics-final        Mite 2        Mite 4
# 63068     robotics-final       robotics-final        Mite 2        Mite 4
# 63069     robotics-final       robotics-final        Mite 2        Mite 4
# 63070     robotics-final       robotics-final        Mite 2        Mite 4
# 63071     robotics-final       robotics-final        Mite 2        Mite 4
# 63072     robotics-final       robotics-final        Mite 2        Mite 4
# 63073     robotics-final       robotics-final        Mite 2        Mite 4
# 63074     robotics-final       robotics-final        Mite 2        Mite 4
# 63075     robotics-final       robotics-final        Mite 2        Mite 4
# 63076     robotics-final       robotics-final        Mite 2        Mite 4
#
#       source_device_name target_device_name source_room target_room  \
# 1           Mite 4 Right        Mite 3 Sink       scott     synergy
# 2           Mite 4 Right       Mite 2 Table       scott     synergy
# 3           Mite 4 Right        Mite 2 Sink       scott     synergy
# 4           Mite 4 Right      Mite 3 Coffee       scott     synergy
# 5           Mite 4 Right       Mite 1 Table       scott     synergy
# 6           Mite 4 Right      Mite 4 Coffee       scott     synergy
# 7           Mite 4 Right      Mite 2 Coffee       scott     synergy
# 8           Mite 4 Right        Mite 4 Sink       scott     synergy
# 9           Mite 4 Right        Mite 2 Left       scott       scott
# 10          Mite 4 Right      Mite 1 Coffee       scott    robotics
# 11          Mite 4 Right        Mite 4 Sink       scott    robotics
# 13          Mite 4 Right        Mite 3 Sink       scott     synergy
# 14          Mite 4 Right       Mite 2 Table       scott     synergy
# 15          Mite 4 Right        Mite 2 Sink       scott     synergy
# 16          Mite 4 Right      Mite 3 Coffee       scott     synergy
# 17          Mite 4 Right       Mite 1 Table       scott     synergy
# 18          Mite 4 Right      Mite 4 Coffee       scott     synergy
# 19          Mite 4 Right      Mite 2 Coffee       scott     synergy
# 20          Mite 4 Right        Mite 4 Sink       scott     synergy
# 21          Mite 4 Right        Mite 2 Left       scott       scott
# 22          Mite 4 Right      Mite 1 Coffee       scott    robotics
# 23          Mite 4 Right        Mite 4 Sink       scott    robotics
# 25          Mite 4 Right        Mite 3 Sink       scott     synergy
# 26          Mite 4 Right       Mite 2 Table       scott     synergy
# 27          Mite 4 Right        Mite 2 Sink       scott     synergy
# 28          Mite 4 Right      Mite 3 Coffee       scott     synergy
# 29          Mite 4 Right       Mite 1 Table       scott     synergy
# 30          Mite 4 Right      Mite 4 Coffee       scott     synergy
# 31          Mite 4 Right      Mite 2 Coffee       scott     synergy
# 32          Mite 4 Right        Mite 4 Sink       scott     synergy
# ...                  ...                ...         ...         ...
# 63047    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63048    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63049    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63050    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63051    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63052    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63053    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63054    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63055    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63056    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63057    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63058    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63059    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63060    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63061    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63062    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63063    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63064    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63065    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63066    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63067    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63068    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63069    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63070    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63071    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63072    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63073    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63074    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63075    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
# 63076    Mite 2 Entrance        Mite 4 Sink    robotics    robotics
#
#       source_placement target_placement            ...             \
# 1                Right             Sink            ...
# 2                Right            Table            ...
# 3                Right             Sink            ...
# 4                Right           Coffee            ...
# 5                Right            Table            ...
# 6                Right           Coffee            ...
# 7                Right           Coffee            ...
# 8                Right             Sink            ...
# 9                Right             Left            ...
# 10               Right           Coffee            ...
# 11               Right             Sink            ...
# 13               Right             Sink            ...
# 14               Right            Table            ...
# 15               Right             Sink            ...
# 16               Right           Coffee            ...
# 17               Right            Table            ...
# 18               Right           Coffee            ...
# 19               Right           Coffee            ...
# 20               Right             Sink            ...
# 21               Right             Left            ...
# 22               Right           Coffee            ...
# 23               Right             Sink            ...
# 25               Right             Sink            ...
# 26               Right            Table            ...
# 27               Right             Sink            ...
# 28               Right           Coffee            ...
# 29               Right            Table            ...
# 30               Right           Coffee            ...
# 31               Right           Coffee            ...
# 32               Right             Sink            ...
# ...                ...              ...            ...
# 63047         Entrance             Sink            ...
# 63048         Entrance             Sink            ...
# 63049         Entrance             Sink            ...
# 63050         Entrance             Sink            ...
# 63051         Entrance             Sink            ...
# 63052         Entrance             Sink            ...
# 63053         Entrance             Sink            ...
# 63054         Entrance             Sink            ...
# 63055         Entrance             Sink            ...
# 63056         Entrance             Sink            ...
# 63057         Entrance             Sink            ...
# 63058         Entrance             Sink            ...
# 63059         Entrance             Sink            ...
# 63060         Entrance             Sink            ...
# 63061         Entrance             Sink            ...
# 63062         Entrance             Sink            ...
# 63063         Entrance             Sink            ...
# 63064         Entrance             Sink            ...
# 63065         Entrance             Sink            ...
# 63066         Entrance             Sink            ...
# 63067         Entrance             Sink            ...
# 63068         Entrance             Sink            ...
# 63069         Entrance             Sink            ...
# 63070         Entrance             Sink            ...
# 63071         Entrance             Sink            ...
# 63072         Entrance             Sink            ...
# 63073         Entrance             Sink            ...
# 63074         Entrance             Sink            ...
# 63075         Entrance             Sink            ...
# 63076         Entrance             Sink            ...
#
#       accuracy_negative accuracy_wt accuracy_positive_wt  \
# 1              0.934135    0.969212             0.830645
# 2              0.961621    0.969212             0.830645
# 3              0.968393    0.969212             0.830645
# 4              0.983671    0.969212             0.830645
# 5              0.915366    0.969212             0.830645
# 6              0.961603    0.969212             0.830645
# 7              0.899032    0.969212             0.830645
# 8              0.859973    0.969212             0.830645
# 9              0.793977    0.969212             0.830645
# 10             0.965194    0.969212             0.830645
# 11             0.942667    0.969212             0.830645
# 13             0.990865    0.976601             0.850394
# 14             0.998706    0.976601             0.850394
# 15             0.983758    0.976601             0.850394
# 16             0.951577    0.976601             0.850394
# 17             0.708014    0.976601             0.850394
# 18             0.332697    0.976601             0.850394
# 19             0.735484    0.976601             0.850394
# 20             0.954577    0.976601             0.850394
# 21             1.000000    0.976601             0.850394
# 22             0.721553    0.976601             0.850394
# 23             0.585778    0.976601             0.850394
# 25             0.640865    0.944581             0.858407
# 26             0.645106    0.944581             0.858407
# 27             0.680860    0.944581             0.858407
# 28             0.682995    0.944581             0.858407
# 29             0.649035    0.944581             0.858407
# 30             0.570236    0.944581             0.858407
# 31             0.591613    0.944581             0.858407
# 32             0.574454    0.944581             0.858407
# ...                 ...         ...                  ...
# 63047          0.999618    0.993080             0.000000
# 63048          0.996941    0.995386             0.000000
# 63049          0.998088    0.971165             0.000000
# 63050          0.999618    0.993080             0.000000
# 63051          1.000000    0.994233             0.000000
# 63052          1.000000    0.997693             0.000000
# 63053          0.996558    0.996540             0.000000
# 63054          1.000000    0.997693             0.666667
# 63055          0.998853    0.981546             0.000000
# 63056          0.999618    0.995386             0.000000
# 63057          0.991969    0.996540             0.000000
# 63058          0.998853    0.985006             0.000000
# 63059          0.998085    0.996540             0.600000
# 63060          0.998085    0.993080             0.428571
# 63061          0.991191    0.966551             0.857143
# 63062          0.998085    0.989619             0.222222
# 63063          1.000000    0.990773             0.000000
# 63064          0.998468    0.986159             0.666667
# 63065          0.998085    0.998847             0.800000
# 63066          0.997319    0.996540             0.666667
# 63067          0.989276    0.982699             0.666667
# 63068          1.000000    0.991926             0.000000
# 63069          1.000000    0.994233             0.000000
# 63070          1.000000    0.995386             0.000000
# 63071          0.990042    0.994233             0.200000
# 63072          1.000000    0.994233             0.000000
# 63073          0.989659    0.988466             0.333333
# 63074          1.000000    0.997693             0.714286
# 63075          1.000000    0.997693             0.666667
# 63076          0.998085    0.967705             0.750000
#
#        accuracy_negative_wt         devices      replica  samples_r  \
# 1                  0.994186  Mite 4->Mite 3  Not replica      370.0
# 2                  0.994186  Mite 4->Mite 2  Not replica      370.0
# 3                  0.994186  Mite 4->Mite 2  Not replica      370.0
# 4                  0.994186  Mite 4->Mite 3  Not replica      370.0
# 5                  0.994186  Mite 4->Mite 1  Not replica      370.0
# 6                  0.994186  Mite 4->Mite 4      Replica      370.0
# 7                  0.994186  Mite 4->Mite 2  Not replica      370.0
# 8                  0.994186  Mite 4->Mite 4      Replica      370.0
# 9                  0.994186  Mite 4->Mite 2  Not replica      370.0
# 10                 0.994186  Mite 4->Mite 1  Not replica      370.0
# 11                 0.994186  Mite 4->Mite 4      Replica      370.0
# 13                 1.000000  Mite 4->Mite 3  Not replica      370.0
# 14                 1.000000  Mite 4->Mite 2  Not replica      370.0
# 15                 1.000000  Mite 4->Mite 2  Not replica      370.0
# 16                 1.000000  Mite 4->Mite 3  Not replica      370.0
# 17                 1.000000  Mite 4->Mite 1  Not replica      370.0
# 18                 1.000000  Mite 4->Mite 4      Replica      370.0
# 19                 1.000000  Mite 4->Mite 2  Not replica      370.0
# 20                 1.000000  Mite 4->Mite 4      Replica      370.0
# 21                 1.000000  Mite 4->Mite 2  Not replica      370.0
# 22                 1.000000  Mite 4->Mite 1  Not replica      370.0
# 23                 1.000000  Mite 4->Mite 4      Replica      370.0
# 25                 0.958512  Mite 4->Mite 3  Not replica      370.0
# 26                 0.958512  Mite 4->Mite 2  Not replica      370.0
# 27                 0.958512  Mite 4->Mite 2  Not replica      370.0
# 28                 0.958512  Mite 4->Mite 3  Not replica      370.0
# 29                 0.958512  Mite 4->Mite 1  Not replica      370.0
# 30                 0.958512  Mite 4->Mite 4      Replica      370.0
# 31                 0.958512  Mite 4->Mite 2  Not replica      370.0
# 32                 0.958512  Mite 4->Mite 4      Replica      370.0
# ...                     ...             ...          ...        ...
# 63047              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63048              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63049              0.979070  Mite 2->Mite 4  Not replica       10.0
# 63050              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63051              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63052              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63053              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63054              0.998843  Mite 2->Mite 4  Not replica       10.0
# 63055              0.983815  Mite 2->Mite 4  Not replica       10.0
# 63056              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63057              1.000000  Mite 2->Mite 4  Not replica       10.0
# 63058              0.990719  Mite 2->Mite 4  Not replica       10.0
# 63059              0.998840  Mite 2->Mite 4  Not replica       20.0
# 63060              0.997674  Mite 2->Mite 4  Not replica       20.0
# 63061              0.967442  Mite 2->Mite 4  Not replica       20.0
# 63062              0.997669  Mite 2->Mite 4  Not replica       20.0
# 63063              1.000000  Mite 2->Mite 4  Not replica       20.0
# 63064              0.987269  Mite 2->Mite 4  Not replica       20.0
# 63065              1.000000  Mite 2->Mite 4  Not replica       20.0
# 63066              0.997685  Mite 2->Mite 4  Not replica       20.0
# 63067              0.986014  Mite 2->Mite 4  Not replica       20.0
# 63068              1.000000  Mite 2->Mite 4  Not replica       20.0
# 63069              0.998841  Mite 2->Mite 4  Not replica       20.0
# 63070              1.000000  Mite 2->Mite 4  Not replica       20.0
# 63071              0.998840  Mite 2->Mite 4  Not replica       20.0
# 63072              1.000000  Mite 2->Mite 4  Not replica       20.0
# 63073              0.993031  Mite 2->Mite 4  Not replica       20.0
# 63074              1.000000  Mite 2->Mite 4  Not replica       20.0
# 63075              1.000000  Mite 2->Mite 4  Not replica       20.0
# 63076              0.968714  Mite 2->Mite 4  Not replica       20.0
#
#        accuracy_change  accuracy_positive_change  accuracy_negative_change
# 1            -0.110403                 -0.459929                 -0.060051
# 2            -0.084814                 -0.492231                 -0.032565
# 3            -0.052356                 -0.232819                 -0.025793
# 4            -0.080060                 -0.442585                 -0.010515
# 5            -0.147800                 -0.724005                 -0.078820
# 6            -0.095551                 -0.516533                 -0.032583
# 7            -0.118020                 -0.368703                 -0.095154
# 8            -0.182267                 -0.604923                 -0.134213
# 9            -0.159785                  0.066374                 -0.200209
# 10           -0.122000                 -0.684757                 -0.028992
# 11           -0.138607                 -0.668841                 -0.051519
# 13           -0.116126                 -0.834817                 -0.009135
# 14           -0.095981                 -0.804662                 -0.001294
# 15           -0.123993                 -0.809633                 -0.016242
# 16           -0.165137                 -0.781737                 -0.048423
# 17           -0.294740                 -0.367496                 -0.291986
# 18           -0.584185                 -0.078011                 -0.667303
# 19           -0.272493                 -0.401575                 -0.264516
# 20           -0.127402                 -0.811024                 -0.045423
# 21           -0.124508                 -0.836844                  0.000000
# 22           -0.284470                 -0.333152                 -0.278447
# 23           -0.421976                 -0.481693                 -0.414222
# 25           -0.321508                 -0.350619                 -0.317647
# 26           -0.319723                 -0.376700                 -0.313407
# 27           -0.277915                 -0.279603                 -0.277652
# 28           -0.274757                 -0.258407                 -0.275517
# 29           -0.314146                 -0.369473                 -0.309478
# 30           -0.401506                 -0.488149                 -0.388276
# 31           -0.397612                 -0.674680                 -0.366899
# 32           -0.391544                 -0.469956                 -0.384059
# ...                ...                       ...                       ...
# 63047         0.001972                  0.000000                 -0.000382
# 63048        -0.003000                  0.000000                 -0.003059
# 63049         0.022364                  0.000000                  0.019018
# 63050         0.001972                  0.000000                 -0.000382
# 63051         0.001199                  0.000000                  0.000000
# 63052        -0.002261                  0.000000                  0.000000
# 63053        -0.004153                  0.083333                 -0.003442
# 63054        -0.002261                 -0.666667                  0.001157
# 63055         0.013125                  0.083333                  0.015038
# 63056        -0.000335                  0.000000                 -0.000382
# 63057        -0.009102                  0.000000                 -0.008031
# 63058         0.009284                  0.000000                  0.008134
# 63059        -0.004534                 -0.600000                 -0.000755
# 63060        -0.001073                 -0.428571                  0.000411
# 63061         0.019745                 -0.669643                  0.023749
# 63062         0.006193                  0.402778                  0.000416
# 63063         0.003137                  0.000000                  0.000000
# 63064         0.009273                 -0.166667                  0.011200
# 63065        -0.006841                 -0.800000                 -0.001915
# 63066        -0.005295                 -0.666667                 -0.000366
# 63067         0.000552                 -0.666667                  0.003262
# 63068         0.001983                  0.000000                  0.000000
# 63069        -0.000324                  0.000000                  0.001159
# 63070        -0.001477                  0.000000                  0.000000
# 63071        -0.009459                 -0.075000                 -0.008798
# 63072        -0.000324                  0.000000                  0.000000
# 63073        -0.003692                 -0.145833                 -0.003372
# 63074        -0.003784                 -0.714286                  0.000000
# 63075        -0.003784                 -0.666667                  0.000000
# 63076         0.024301                 -0.750000                  0.029371
#
# [57080 rows x 28 columns]
