# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

width = 12
height = 7
plt.rcParams["figure.figsize"] = (width, height)


from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import tflscripts
import json
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from sklearn import tree
import pickle

configuration = tflscripts.read_configuration()

# %%
df_tested = pd.read_pickle('results_with_accuracy_classified.p')

# %%
cases = df_tested[['target_device_name', 'target_dataset']].drop_duplicates()
plt.rcParams["figure.figsize"] = (5, 3)

for _, case in cases.iterrows():
    device_name = case['target_device_name']
    dataset = case['target_dataset']
    df_relevant = df_tested.loc[df_tested.target_device_name == device_name]
    df_relevant = df_relevant.loc[df_relevant.target_dataset == dataset]

    good_models = df_relevant.loc[df_relevant.accuracy_bin == 1]
    predicted_models = df_relevant.loc[df_relevant.predictions == 1]
    
    true_positives = good_models.loc[good_models.predictions == 1]
    false_positives = predicted_models.loc[predicted_models.accuracy_bin != 1]
    true_negatives = good_models.loc[good_models.predictions == 0]

    pd.Series({
        'True positives': len(true_positives),
        'False positives': len(false_positives),
        'True negatives': len(true_negatives),
    }).plot.bar()
    plt.title(device_name + ' in ' + dataset)
    plt.show()

# %%
### plt.rcParams["figure.figsize"] = (7, 5)

for _, case in cases.iterrows():
    device_name = case['target_device_name']
    dataset = case['target_dataset']
    print(dataset, device_name)
    df_relevant = df_tested.loc[df_tested.target_device_name == device_name]
    df_relevant = df_relevant.loc[df_relevant.target_dataset == dataset]

    good_models = df_relevant.loc[df_relevant.accuracy_bin == 1]
    predicted_models = df_relevant.loc[df_relevant.predictions == 1]

    predicted_models = predicted_models[['label', 'accuracy_positive']]
    predicted_models = predicted_models.rename(columns={'accuracy_positive': 'Avg. accuracy of predicted models'})
    predicted_models = predicted_models.groupby(['label'])['Avg. accuracy of predicted models'].mean()

    good_models = good_models[['label', 'accuracy_positive']]
    good_models = good_models.rename(columns={'accuracy_positive': 'Avg. accuracy of actual models'})
    good_models = good_models.groupby(['label'])['Avg. accuracy of actual models'].mean()

    pd.concat([predicted_models, good_models], axis=1).plot.bar()

    plt.title(device_name + ' in ' + dataset)
    plt.show()
# Out:
# synergy-final-iter2 Mite 3 Coffee
# synergy-final-iter1 Mite 3 Sink
# synergy-final-iter1 Mite 2 Table
# synergy-final-iter2 Mite 2 Sink
# synergy-final-iter4 Mite 1 Table
# synergy-final-iter4 Mite 4 Coffee
# synergy-final-iter5 Mite 2 Coffee
# synergy-final-iter5 Mite 4 Sink
# scott-final-iter1 Mite 2 Left
# scott-final-iter1 Mite 4 Right
# robotics-final Mite 1 Coffee
# robotics-final Mite 4 Sink
# synergy-final-iter1 Mite 1 Coffee
# synergy-final-iter2 Mite 1 Table
# synergy-final-iter4 Mite 2 Sink
# synergy-final-iter5 Mite 1 Table
# scott-final-iter1 Mite 1 Pantry
# robotics-final Mite 2 Entrance

# %%
list(df_relevant.loc[df_relevant.predictions == 2].iterrows())[0][1]
# Out:
# source_dataset                          scott-final-iter1
# target_dataset                          scott-final-iter1
# source_device                                      Mite 4
# target_device                                      Mite 2
# source_device_name                           Mite 4 Right
# target_device_name                            Mite 2 Left
# source_room                                         scott
# target_room                                         scott
# source_placement                                    Right
# target_placement                                     Left
# type_of_transfer      Same device type in different place
# classifier                                            SVM
# label                                              Dishes
# features                                              All
# accuracy                                         0.993905
# accuracy_positive                                0.958678
# accuracy_negative                                       1
# accuracy_bin                                            2
# predictions                                             2
# Name: 18771, dtype: object

# %%
for _, case in cases.iterrows():
    device_name = case['target_device_name']
    dataset = case['target_dataset']
    print(dataset, device_name)
    df_relevant = df_tested.loc[df_tested.target_device_name == device_name]
    df_relevant = df_relevant.loc[df_relevant.target_dataset == dataset]
    
    print(df_relevant.loc[df_relevant.accuracy_bin == 2][['source_dataset', 'source_device', 'label']].drop_duplicates())
    print(df_relevant.loc[df_relevant.predictions == 2][['source_dataset', 'source_device', 'label']].drop_duplicates())
    
    print('Options', len(df_relevant))
    print('Good options', len(df_relevant.loc[df_relevant.accuracy_bin == 2]))
    print('Good option labels', len(df_relevant.loc[df_relevant.accuracy_bin == 2].label.unique()))
    print(df_relevant.loc[df_relevant.accuracy_bin == 2].label.unique())
    print('Predicted options', len(df_relevant.loc[df_relevant.predictions == 2]))
    print('Predicted option labels', len(df_relevant.loc[df_relevant.predictions == 2].label.unique()))
    print()
# Out:
# synergy-final-iter1 Mite 3 Sink
#             source_dataset source_device                   label
# 181    synergy-final-iter2        Mite 2               Microwave
# 901    synergy-final-iter2        Mite 2                  Dishes
# 1381   synergy-final-iter2        Mite 2  Microwave button press
# 1908   synergy-final-iter2        Mite 3               Microwave
# 2748   synergy-final-iter2        Mite 3                  Dishes
# 3058   synergy-final-iter2        Mite 3  Microwave button press
# 6607   synergy-final-iter5        Mite 2               Microwave
# 8125   synergy-final-iter5        Mite 4               Microwave
# 13003  synergy-final-iter1        Mite 2               Microwave
# 13747  synergy-final-iter1        Mite 2                  Dishes
# 14203  synergy-final-iter1        Mite 2  Microwave button press
#             source_dataset source_device                   label
# 217    synergy-final-iter2        Mite 2               Microwave
# 901    synergy-final-iter2        Mite 2                  Dishes
# 1381   synergy-final-iter2        Mite 2  Microwave button press
# 2748   synergy-final-iter2        Mite 3                  Dishes
# 3058   synergy-final-iter2        Mite 3  Microwave button press
# 3346   synergy-final-iter2        Mite 3                Knocking
# 7147   synergy-final-iter5        Mite 2           Chopping food
# 8125   synergy-final-iter5        Mite 4               Microwave
# 8689   synergy-final-iter5        Mite 4           Chopping food
# 9433   synergy-final-iter5        Mite 4   Microwave door closed
# 13399  synergy-final-iter1        Mite 2           Chopping food
# 13747  synergy-final-iter1        Mite 2                  Dishes
# 14071  synergy-final-iter1        Mite 2   Microwave door closed
# 14243  synergy-final-iter1        Mite 2  Microwave button press
# Options 241
# Good options 29
# Good option labels 3
# ['Microwave' 'Dishes' 'Microwave button press']
# Predicted options 28
# Predicted option labels 6
#
# synergy-final-iter2 Mite 3 Coffee
#             source_dataset source_device                   label
# 183    synergy-final-iter2        Mite 2               Microwave
# 1163   synergy-final-iter2        Mite 2            Conversation
# 1239   synergy-final-iter2        Mite 2   Microwave door closed
# 1399   synergy-final-iter2        Mite 2  Microwave button press
# 1514   synergy-final-iter2        Mite 2                Knocking
# 3565   synergy-final-iter4        Mite 4                  Dishes
# 3745   synergy-final-iter4        Mite 4           Chopping food
# 4561   synergy-final-iter4        Mite 4   Microwave door closed
# 6718   synergy-final-iter5        Mite 2               Microwave
# 7102   synergy-final-iter5        Mite 2                  Dishes
# 7894   synergy-final-iter5        Mite 2   Microwave door closed
# 13005  synergy-final-iter1        Mite 2               Microwave
# 13365  synergy-final-iter1        Mite 2           Chopping food
# 13725  synergy-final-iter1        Mite 2                  Dishes
# 14025  synergy-final-iter1        Mite 2   Microwave door closed
# 14301  synergy-final-iter1        Mite 2  Microwave button press
# 14685  synergy-final-iter1        Mite 3               Microwave
# 15729  synergy-final-iter1        Mite 3   Microwave door closed
#             source_dataset source_device                   label
# 183    synergy-final-iter2        Mite 2               Microwave
# 1263   synergy-final-iter2        Mite 2   Microwave door closed
# 1407   synergy-final-iter2        Mite 2  Microwave button press
# 3565   synergy-final-iter4        Mite 4                  Dishes
# 3745   synergy-final-iter4        Mite 4           Chopping food
# 6718   synergy-final-iter5        Mite 2               Microwave
# 7078   synergy-final-iter5        Mite 2                  Dishes
# 7150   synergy-final-iter5        Mite 2           Chopping food
# 13401  synergy-final-iter1        Mite 2           Chopping food
# 13725  synergy-final-iter1        Mite 2                  Dishes
# 14301  synergy-final-iter1        Mite 2  Microwave button press
# 15729  synergy-final-iter1        Mite 3   Microwave door closed
# 15885  synergy-final-iter1        Mite 3  Microwave button press
# Options 218
# Good options 35
# Good option labels 7
# ['Microwave' 'Conversation' 'Microwave door closed'
#  'Microwave button press' 'Knocking' 'Dishes' 'Chopping food']
# Predicted options 21
# Predicted option labels 5
#
# synergy-final-iter5 Mite 4 Sink
#             source_dataset source_device                  label
# 1027   synergy-final-iter2        Mite 2                 Dishes
# 1231   synergy-final-iter2        Mite 2  Microwave door closed
# 3712   synergy-final-iter4        Mite 4                 Dishes
# 3772   synergy-final-iter4        Mite 4          Chopping food
# 4128   synergy-final-iter4        Mite 4                  Alarm
# 4376   synergy-final-iter4        Mite 4   Cupboard door opened
# 4388   synergy-final-iter4        Mite 4   Cupboard door closed
# 4520   synergy-final-iter4        Mite 4   Microwave done chime
# 5265   synergy-final-iter4        Mite 1          Chopping food
# 5489   synergy-final-iter4        Mite 1                  Alarm
# 5797   synergy-final-iter4        Mite 1   Cupboard door closed
# 5917   synergy-final-iter4        Mite 1   Microwave done chime
# 6317   synergy-final-iter4        Mite 1        Vacuum cleaning
# 6393   synergy-final-iter5        Mite 2        Vacuum cleaning
# 6453   synergy-final-iter5        Mite 2        Blender running
# 6521   synergy-final-iter5        Mite 2                  Alarm
# 6577   synergy-final-iter5        Mite 2              Microwave
# 6961   synergy-final-iter5        Mite 2                 Dishes
# 7721   synergy-final-iter5        Mite 2   Cupboard door closed
# 7845   synergy-final-iter5        Mite 2   Microwave done chime
# 14749  synergy-final-iter1        Mite 3              Microwave
#             source_dataset source_device                  label
# 223    synergy-final-iter2        Mite 2              Microwave
# 1902   synergy-final-iter2        Mite 3              Microwave
# 2945   synergy-final-iter2        Mite 3  Microwave door closed
# 3712   synergy-final-iter4        Mite 4                 Dishes
# 4128   synergy-final-iter4        Mite 4                  Alarm
# 4400   synergy-final-iter4        Mite 4   Cupboard door closed
# 4520   synergy-final-iter4        Mite 4   Microwave done chime
# 5489   synergy-final-iter4        Mite 1                  Alarm
# 5797   synergy-final-iter4        Mite 1   Cupboard door closed
# 6317   synergy-final-iter4        Mite 1        Vacuum cleaning
# 6393   synergy-final-iter5        Mite 2        Vacuum cleaning
# 6453   synergy-final-iter5        Mite 2        Blender running
# 6513   synergy-final-iter5        Mite 2                  Alarm
# 6577   synergy-final-iter5        Mite 2              Microwave
# 6817   synergy-final-iter5        Mite 2                 Kettle
# 6961   synergy-final-iter5        Mite 2                 Dishes
# 7709   synergy-final-iter5        Mite 2   Cupboard door opened
# 7733   synergy-final-iter5        Mite 2   Cupboard door closed
# 14053  synergy-final-iter1        Mite 2  Microwave door closed
# 14737  synergy-final-iter1        Mite 3              Microwave
# 15709  synergy-final-iter1        Mite 3  Microwave door closed
# Options 331
# Good options 44
# Good option labels 10
# ['Dishes' 'Microwave door closed' 'Chopping food' 'Alarm'
#  'Cupboard door opened' 'Cupboard door closed' 'Microwave done chime'
#  'Vacuum cleaning' 'Blender running' 'Microwave']
# Predicted options 34
# Predicted option labels 10
#
# synergy-final-iter1 Mite 2 Table
#            source_dataset source_device                   label
# 2617  synergy-final-iter2        Mite 3                  Dishes
# 3099  synergy-final-iter2        Mite 3  Microwave button press
#             source_dataset source_device                   label
# 1370   synergy-final-iter2        Mite 2   Microwave door closed
# 1494   synergy-final-iter2        Mite 2  Microwave button press
# 2257   synergy-final-iter2        Mite 3           Chopping food
# 3099   synergy-final-iter2        Mite 3  Microwave button press
# 3215   synergy-final-iter2        Mite 3                Knocking
# 8114   synergy-final-iter5        Mite 4               Microwave
# 14743  synergy-final-iter1        Mite 3               Microwave
# 15907  synergy-final-iter1        Mite 3  Microwave button press
# Options 214
# Good options 2
# Good option labels 2
# ['Dishes' 'Microwave button press']
# Predicted options 10
# Predicted option labels 5
#
# synergy-final-iter4 Mite 1 Table
#            source_dataset source_device                 label
# 4078  synergy-final-iter4        Mite 4                 Alarm
# 4398  synergy-final-iter4        Mite 4  Cupboard door closed
# 6391  synergy-final-iter5        Mite 2       Vacuum cleaning
# 6467  synergy-final-iter5        Mite 2       Blender running
# 6511  synergy-final-iter5        Mite 2                 Alarm
# 7909  synergy-final-iter5        Mite 4       Vacuum cleaning
# 7981  synergy-final-iter5        Mite 4       Blender running
# 8077  synergy-final-iter5        Mite 4                 Alarm
#             source_dataset source_device                  label
# 1264   synergy-final-iter2        Mite 2  Microwave door closed
# 2942   synergy-final-iter2        Mite 3  Microwave door closed
# 4078   synergy-final-iter4        Mite 4                  Alarm
# 4398   synergy-final-iter4        Mite 4   Cupboard door closed
# 6391   synergy-final-iter5        Mite 2        Vacuum cleaning
# 6455   synergy-final-iter5        Mite 2        Blender running
# 6511   synergy-final-iter5        Mite 2                  Alarm
# 6575   synergy-final-iter5        Mite 2              Microwave
# 7151   synergy-final-iter5        Mite 2          Chopping food
# 7707   synergy-final-iter5        Mite 2   Cupboard door opened
# 7731   synergy-final-iter5        Mite 2   Cupboard door closed
# 7909   synergy-final-iter5        Mite 4        Vacuum cleaning
# 7981   synergy-final-iter5        Mite 4        Blender running
# 8077   synergy-final-iter5        Mite 4                  Alarm
# 9249   synergy-final-iter5        Mite 4   Cupboard door closed
# 14194  synergy-final-iter1        Mite 2  Microwave door closed
# 14494  synergy-final-iter1        Mite 2               Knocking
# Options 322
# Good options 20
# Good option labels 4
# ['Alarm' 'Cupboard door closed' 'Vacuum cleaning' 'Blender running']
# Predicted options 30
# Predicted option labels 9
#
# synergy-final-iter4 Mite 4 Coffee
#             source_dataset source_device                  label
# 1265   synergy-final-iter2        Mite 2  Microwave door closed
# 2368   synergy-final-iter2        Mite 3          Chopping food
# 2907   synergy-final-iter2        Mite 3  Microwave door closed
# 5487   synergy-final-iter4        Mite 1                  Alarm
# 5823   synergy-final-iter4        Mite 1   Cupboard door closed
# 5915   synergy-final-iter4        Mite 1   Microwave done chime
# 6383   synergy-final-iter4        Mite 1        Blender running
# 6396   synergy-final-iter5        Mite 2        Vacuum cleaning
# 6452   synergy-final-iter5        Mite 2        Blender running
# 6512   synergy-final-iter5        Mite 2                  Alarm
# 6600   synergy-final-iter5        Mite 2              Microwave
# 6984   synergy-final-iter5        Mite 2                 Dishes
# 7140   synergy-final-iter5        Mite 2          Chopping food
# 7764   synergy-final-iter5        Mite 2   Cupboard door closed
# 7852   synergy-final-iter5        Mite 2   Microwave done chime
# 7910   synergy-final-iter5        Mite 4        Vacuum cleaning
# 7978   synergy-final-iter5        Mite 4        Blender running
# 8030   synergy-final-iter5        Mite 4                  Alarm
# 8130   synergy-final-iter5        Mite 4              Microwave
# 8670   synergy-final-iter5        Mite 4          Chopping food
# 9238   synergy-final-iter5        Mite 4   Cupboard door closed
# 14051  synergy-final-iter1        Mite 2  Microwave door closed
# 14723  synergy-final-iter1        Mite 3              Microwave
#             source_dataset source_device                  label
# 185    synergy-final-iter2        Mite 2              Microwave
# 1265   synergy-final-iter2        Mite 2  Microwave door closed
# 1672   synergy-final-iter2        Mite 2               Knocking
# 1900   synergy-final-iter2        Mite 3              Microwave
# 2236   synergy-final-iter2        Mite 3          Chopping food
# 3350   synergy-final-iter2        Mite 3               Knocking
# 5487   synergy-final-iter4        Mite 1                  Alarm
# 5823   synergy-final-iter4        Mite 1   Cupboard door closed
# 6383   synergy-final-iter4        Mite 1        Blender running
# 6396   synergy-final-iter5        Mite 2        Vacuum cleaning
# 6452   synergy-final-iter5        Mite 2        Blender running
# 6512   synergy-final-iter5        Mite 2                  Alarm
# 6600   synergy-final-iter5        Mite 2              Microwave
# 6996   synergy-final-iter5        Mite 2                 Dishes
# 7140   synergy-final-iter5        Mite 2          Chopping food
# 7732   synergy-final-iter5        Mite 2   Cupboard door closed
# 7852   synergy-final-iter5        Mite 2   Microwave done chime
# 7910   synergy-final-iter5        Mite 4        Vacuum cleaning
# 7978   synergy-final-iter5        Mite 4        Blender running
# 8030   synergy-final-iter5        Mite 4                  Alarm
# 8130   synergy-final-iter5        Mite 4              Microwave
# 8670   synergy-final-iter5        Mite 4          Chopping food
# 9238   synergy-final-iter5        Mite 4   Cupboard door closed
# 14075  synergy-final-iter1        Mite 2  Microwave door closed
# Options 304
# Good options 53
# Good option labels 9
# ['Microwave door closed' 'Chopping food' 'Alarm' 'Cupboard door closed'
#  'Microwave done chime' 'Blender running' 'Vacuum cleaning' 'Microwave'
#  'Dishes']
# Predicted options 44
# Predicted option labels 10
#
# synergy-final-iter5 Mite 2 Coffee
#             source_dataset source_device                  label
# 1230   synergy-final-iter2        Mite 2  Microwave door closed
# 1529   synergy-final-iter2        Mite 2               Knocking
# 2369   synergy-final-iter2        Mite 3          Chopping food
# 2908   synergy-final-iter2        Mite 3  Microwave door closed
# 3183   synergy-final-iter2        Mite 3               Knocking
# 3399   synergy-final-iter4        Mite 4                 Kettle
# 3591   synergy-final-iter4        Mite 4                 Dishes
# 3759   synergy-final-iter4        Mite 4          Chopping food
# 4079   synergy-final-iter4        Mite 4                  Alarm
# 4387   synergy-final-iter4        Mite 4   Cupboard door closed
# 4731   synergy-final-iter4        Mite 4  Microwave door closed
# 4743   synergy-final-iter4        Mite 4               Knocking
# 5180   synergy-final-iter4        Mite 1          Chopping food
# 5784   synergy-final-iter4        Mite 1   Cupboard door closed
# 6364   synergy-final-iter4        Mite 1        Vacuum cleaning
# 6384   synergy-final-iter4        Mite 1        Blender running
# 7911   synergy-final-iter5        Mite 4        Vacuum cleaning
# 7971   synergy-final-iter5        Mite 4        Blender running
# 8043   synergy-final-iter5        Mite 4                  Alarm
# 8659   synergy-final-iter5        Mite 4          Chopping food
# 9247   synergy-final-iter5        Mite 4   Cupboard door closed
# 13368  synergy-final-iter1        Mite 2          Chopping food
# 14088  synergy-final-iter1        Mite 2  Microwave door closed
# 14472  synergy-final-iter1        Mite 2               Knocking
#             source_dataset source_device                  label
# 222    synergy-final-iter2        Mite 2              Microwave
# 1374   synergy-final-iter2        Mite 2  Microwave door closed
# 1901   synergy-final-iter2        Mite 3              Microwave
# 3351   synergy-final-iter2        Mite 3               Knocking
# 3591   synergy-final-iter4        Mite 4                 Dishes
# 3771   synergy-final-iter4        Mite 4          Chopping food
# 4079   synergy-final-iter4        Mite 4                  Alarm
# 4387   synergy-final-iter4        Mite 4   Cupboard door closed
# 4519   synergy-final-iter4        Mite 4   Microwave done chime
# 4707   synergy-final-iter4        Mite 4  Microwave door closed
# 5180   synergy-final-iter4        Mite 1          Chopping food
# 5784   synergy-final-iter4        Mite 1   Cupboard door closed
# 6364   synergy-final-iter4        Mite 1        Vacuum cleaning
# 6384   synergy-final-iter4        Mite 1        Blender running
# 7911   synergy-final-iter5        Mite 4        Vacuum cleaning
# 7971   synergy-final-iter5        Mite 4        Blender running
# 8043   synergy-final-iter5        Mite 4                  Alarm
# 8131   synergy-final-iter5        Mite 4              Microwave
# 8335   synergy-final-iter5        Mite 4                 Kettle
# 8803   synergy-final-iter5        Mite 4          Chopping food
# 9251   synergy-final-iter5        Mite 4   Cupboard door closed
# 14052  synergy-final-iter1        Mite 2  Microwave door closed
# 14496  synergy-final-iter1        Mite 2               Knocking
# Options 288
# Good options 50
# Good option labels 9
# ['Microwave door closed' 'Knocking' 'Chopping food' 'Kettle' 'Dishes'
#  'Alarm' 'Cupboard door closed' 'Vacuum cleaning' 'Blender running']
# Predicted options 39
# Predicted option labels 11
#
# synergy-final-iter2 Mite 2 Sink
#             source_dataset source_device                   label
# 1910   synergy-final-iter2        Mite 3               Microwave
# 2618   synergy-final-iter2        Mite 3                  Dishes
# 2905   synergy-final-iter2        Mite 3   Microwave door closed
# 3076   synergy-final-iter2        Mite 3  Microwave button press
# 4584   synergy-final-iter4        Mite 4   Microwave door closed
# 6573   synergy-final-iter5        Mite 2               Microwave
# 8127   synergy-final-iter5        Mite 4               Microwave
# 13040  synergy-final-iter1        Mite 2               Microwave
# 13724  synergy-final-iter1        Mite 2                  Dishes
# 14060  synergy-final-iter1        Mite 2   Microwave door closed
# 14204  synergy-final-iter1        Mite 2  Microwave button press
# 14444  synergy-final-iter1        Mite 2                Knocking
# 14708  synergy-final-iter1        Mite 3               Microwave
# 15404  synergy-final-iter1        Mite 3                  Dishes
# 15728  synergy-final-iter1        Mite 3   Microwave door closed
# 15884  synergy-final-iter1        Mite 3  Microwave button press
#             source_dataset source_device                   label
# 2618   synergy-final-iter2        Mite 3                  Dishes
# 5153   synergy-final-iter4        Mite 1           Chopping food
# 6597   synergy-final-iter5        Mite 2               Microwave
# 7149   synergy-final-iter5        Mite 2           Chopping food
# 8127   synergy-final-iter5        Mite 4               Microwave
# 8487   synergy-final-iter5        Mite 4                  Dishes
# 13064  synergy-final-iter1        Mite 2               Microwave
# 13724  synergy-final-iter1        Mite 2                  Dishes
# 14204  synergy-final-iter1        Mite 2  Microwave button press
# 14492  synergy-final-iter1        Mite 2                Knocking
# 14708  synergy-final-iter1        Mite 3               Microwave
# 15440  synergy-final-iter1        Mite 3                  Dishes
# 15980  synergy-final-iter1        Mite 3  Microwave button press
# Options 230
# Good options 48
# Good option labels 5
# ['Microwave' 'Dishes' 'Microwave door closed' 'Microwave button press'
#  'Knocking']
# Predicted options 25
# Predicted option labels 5
#
# robotics-final Mite 1 Coffee
#        source_dataset source_device          label
# 10013  robotics-final        Mite 4  Chopping food
#        source_dataset source_device          label
# 10037  robotics-final        Mite 4  Chopping food
# Options 49
# Good options 4
# Good option labels 1
# ['Chopping food']
# Predicted options 3
# Predicted option labels 1
#
# robotics-final Mite 4 Sink
#        source_dataset source_device          label
# 11753  robotics-final        Mite 1  Chopping food
# 12077  robotics-final        Mite 1         Dishes
#        source_dataset source_device          label
# 11753  robotics-final        Mite 1  Chopping food
# Options 51
# Good options 3
# Good option labels 2
# ['Chopping food' 'Dishes']
# Predicted options 1
# Predicted option labels 1
#
# scott-final-iter1 Mite 4 Right
#           source_dataset source_device     label
# 17091  scott-final-iter1        Mite 2    Dishes
# 17727  scott-final-iter1        Mite 2  Knocking
#           source_dataset source_device                   label
# 17439  scott-final-iter1        Mite 2   Microwave door closed
# 17607  scott-final-iter1        Mite 2  Microwave button press
# Options 43
# Good options 3
# Good option labels 2
# ['Dishes' 'Knocking']
# Predicted options 3
# Predicted option labels 2
#
# scott-final-iter1 Mite 2 Left
#           source_dataset source_device   label
# 18771  scott-final-iter1        Mite 4  Dishes
#           source_dataset source_device                   label
# 18771  scott-final-iter1        Mite 4                  Dishes
# 19287  scott-final-iter1        Mite 4  Microwave button press
# Options 44
# Good options 5
# Good option labels 1
# ['Dishes']
# Predicted options 3
# Predicted option labels 2

# %%
df = pd.DataFrame({'predicted': predicted, 'actual': y_test})
pivoted = df.pivot_table(index='predicted', columns='actual', aggfunc=len, fill_value=0)
plt.pcolor(pivoted)
plt.colorbar()
pivoted
# Out:
# actual       0   1   2
# predicted
# 0          553  25  32
# 1           40  14  12
# 2           20  17  63

# %%
from IPython.display import Image
import pydotplus

clf = ppl.named_steps['clf']

dot_data = tree.export_graphviz(clf, out_file=None,
#                                 feature_names=iris.feature_names,
#                                 class_names=iris.target_names,
                                filled=True, rounded=True,
                                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf("decision_tree.pdf")
# Out:
# True
