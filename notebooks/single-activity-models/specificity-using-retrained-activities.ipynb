# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

width = 12
height = 7
plt.rcParams["figure.figsize"] = (width, height)


from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import tflscripts
import json
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import tree
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.decomposition import TruncatedSVD
import pickle

configuration = tflscripts.read_configuration()
df_first_predictions = pd.read_pickle('results_first_metaclassifier.p')
df = pd.read_pickle('results.p')

# %%
def to_key(row):
    columns =  ['source_placement', 'target_placement', 'source_room', 'target_room', 'source_device', 'target_device', 'label']
    return '_'.join(row[columns])

def to_target_key(row):
    columns =  ['target_placement', 'target_room', 'target_device', 'label']
    return '_'.join(row[columns])

def to_source_key(row):
    columns =  ['target_placement', 'target_room', 'target_device', 'label']
    return '_'.join(row[columns])

def to_transfer_with_label_key(row):
    columns =  ['source_placement', 'target_placement', 'source_room', 'target_room', 'source_device_type', 'target_device_type', 'label']
    return '_'.join(row[columns])

def to_transfer_key(row):
    columns =  ['source_placement', 'target_placement', 'source_room', 'target_room', 'source_device_type', 'target_device_type']
    return '_'.join(row[columns])

def build_transfer_key(source_placement, target_placement, source_room, target_room, source_device_type, target_device_type):
    return '_'.join([source_placement, target_placement, source_room, target_room, source_device_type, target_device_type])


df['key'] = [to_key(row) for i, row in df.iterrows()]
df['target_key'] = [to_target_key(row) for i, row in df.iterrows()]
df['source_key'] = [to_source_key(row) for i, row in df.iterrows()]
df['transfer_with_label_key'] = [to_transfer_with_label_key(row) for i, row in df.iterrows()]
df['transfer_key'] = [to_transfer_key(row) for i, row in df.iterrows()]

# %%
predictions = df_first_predictions.predictions
df['first_predictions'] = [predictions.get(k) for k in df.key]

# %%
df_same_model = df.loc[(df.classifier == 'SVM') & (df.features_name == 'All')]

# %%
df_same_model = df_same_model.loc[(df_same_model.first_predictions == 0) | (df_same_model.first_predictions == 1)]

# %%
threshold = 0.75
to_use_for_specificity = df_same_model.loc[(df_same_model.f1_target_wt >= threshold) & (
    (df_same_model.f1_wt < threshold) | (df_same_model.first_predictions == 0)
)]

# %%
activities_to_retrain = {}
for transfer in to_use_for_specificity.transfer_key.unique():
    labels = to_use_for_specificity.loc[to_use_for_specificity.transfer_key == transfer].label.unique()
    activities_to_retrain[transfer] = labels.tolist()

output = open('activities_to_retrain.p', 'wb')
pickle.dump(activities_to_retrain, output)
output.close()

# %%
activities_to_retrain
# Out:
# {'Coffee_Coffee_robotics_robotics_Matrix_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Knocking',
#   'Microwave'],
#  'Coffee_Coffee_robotics_robotics_Matrix_XDK': ['Chopping food', 'Dishes'],
#  'Coffee_Coffee_robotics_robotics_Mite_XDK': ['Chopping food', 'Dishes'],
#  'Coffee_Coffee_robotics_robotics_XDK_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Knocking',
#   'Microwave'],
#  'Coffee_Coffee_robotics_synergy_Mite_Mite': ['Chopping food',
#   'Conversation',
#   'Kettle',
#   'Microwave',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed'],
#  'Coffee_Coffee_synergy_robotics_Mite_Mite': ['Chopping food',
#   'Kettle',
#   'Microwave',
#   'Coffee',
#   'Knocking'],
#  'Coffee_Coffee_synergy_synergy_Matrix_Mite': ['Chopping food',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Microwave',
#   'Alarm',
#   'Blender running',
#   'Coffee',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Knocking',
#   'Microwave door closed',
#   'Soap dispensed'],
#  'Coffee_Coffee_synergy_synergy_Matrix_XDK': ['Chopping food',
#   'Conversation',
#   'Dishes',
#   'Vacuum cleaning'],
#  'Coffee_Coffee_synergy_synergy_Mite_Matrix': ['Chopping food',
#   'Blender running',
#   'Alarm'],
#  'Coffee_Coffee_synergy_synergy_Mite_Mite': ['Kettle',
#   'Knocking',
#   'Soap dispensed',
#   'Coffee',
#   'Cupboard door opened'],
#  'Coffee_Coffee_synergy_synergy_Mite_XDK': ['Conversation',
#   'Dishes',
#   'Blender running'],
#  'Coffee_Coffee_synergy_synergy_XDK_Matrix': ['Microwave',
#   'Chopping food',
#   'Alarm',
#   'Blender running',
#   'Vacuum cleaning'],
#  'Coffee_Coffee_synergy_synergy_XDK_Mite': ['Dishes',
#   'Kettle',
#   'Microwave',
#   'Conversation',
#   'Alarm',
#   'Coffee',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Knocking',
#   'Microwave door closed',
#   'Soap dispensed',
#   'Blender running'],
#  'Coffee_Entrance_robotics_robotics_Mite_Mite': ['Microwave'],
#  'Coffee_Entrance_synergy_robotics_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Coffee'],
#  'Coffee_Left_robotics_scott_Mite_Mite': ['Coffee',
#   'Conversation',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed'],
#  'Coffee_Left_synergy_scott_Mite_Mite': ['Microwave',
#   'Coffee',
#   'Knocking',
#   'Cupboard door opened',
#   'Soap dispensed',
#   'Microwave door closed'],
#  'Coffee_Pantry_robotics_scott_Mite_Mite': ['Conversation'],
#  'Coffee_Pantry_synergy_scott_Mite_Mite': ['Cupboard door opened'],
#  'Coffee_Right_robotics_scott_Mite_Mite': ['Chopping food',
#   'Conversation',
#   'Kettle',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed'],
#  'Coffee_Right_synergy_scott_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Soap dispensed',
#   'Cupboard door closed'],
#  'Coffee_Sink_robotics_robotics_Mite_Mite': ['Coffee',
#   'Microwave',
#   'Microwave door closed'],
#  'Coffee_Sink_robotics_synergy_Mite_Mite': ['Conversation',
#   'Microwave',
#   'Microwave button press',
#   'Kettle',
#   'Knocking',
#   'Microwave door closed'],
#  'Coffee_Sink_synergy_robotics_Mite_Mite': ['Kettle', 'Microwave', 'Coffee'],
#  'Coffee_Sink_synergy_synergy_Mite_Mite': ['Microwave button press',
#   'Kettle',
#   'Chopping food',
#   'Conversation',
#   'Microwave',
#   'Cupboard door opened',
#   'Knocking',
#   'Microwave done chime',
#   'Microwave door closed',
#   'Soap dispensed'],
#  'Coffee_Table_robotics_synergy_Mite_Mite': ['Chopping food',
#   'Conversation',
#   'Microwave',
#   'Microwave button press',
#   'Dishes'],
#  'Coffee_Table_synergy_synergy_Mite_Mite': ['Microwave button press',
#   'Conversation',
#   'Chopping food',
#   'Microwave'],
#  'Entrance_Coffee_robotics_robotics_Mite_Mite': ['Knocking'],
#  'Entrance_Coffee_robotics_synergy_Mite_Mite': ['Conversation',
#   'Dishes',
#   'Kettle',
#   'Microwave',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed'],
#  'Entrance_Entrance_robotics_robotics_Matrix_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Microwave'],
#  'Entrance_Entrance_robotics_robotics_Matrix_XDK': ['Conversation'],
#  'Entrance_Entrance_robotics_robotics_Mite_Matrix': ['Chopping food'],
#  'Entrance_Entrance_robotics_robotics_Mite_XDK': ['Conversation'],
#  'Entrance_Entrance_robotics_robotics_XDK_Matrix': ['Chopping food'],
#  'Entrance_Entrance_robotics_robotics_XDK_Mite': ['Chopping food',
#   'Coffee',
#   'Dishes',
#   'Kettle',
#   'Microwave'],
#  'Entrance_Left_robotics_scott_Mite_Mite': ['Coffee',
#   'Conversation',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed'],
#  'Entrance_Pantry_robotics_scott_Mite_Mite': ['Conversation'],
#  'Entrance_Right_robotics_scott_Mite_Mite': ['Conversation',
#   'Kettle',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed'],
#  'Entrance_Sink_robotics_robotics_Mite_Mite': ['Coffee',
#   'Microwave',
#   'Microwave door closed'],
#  'Entrance_Sink_robotics_synergy_Mite_Mite': ['Conversation',
#   'Dishes',
#   'Microwave',
#   'Microwave button press',
#   'Kettle',
#   'Knocking',
#   'Microwave door closed'],
#  'Entrance_Table_robotics_synergy_Mite_Mite': ['Chopping food',
#   'Microwave',
#   'Microwave button press',
#   'Conversation'],
#  'Left_Coffee_scott_robotics_Mite_Mite': ['Chopping food',
#   'Coffee',
#   'Kettle',
#   'Knocking',
#   'Microwave'],
#  'Left_Coffee_scott_synergy_Mite_Mite': ['Chopping food',
#   'Kettle',
#   'Microwave',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Soap dispensed'],
#  'Left_Entrance_scott_robotics_Mite_Mite': ['Coffee', 'Kettle', 'Microwave'],
#  'Left_Left_scott_scott_Matrix_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Dishes',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Soap dispensed'],
#  'Left_Left_scott_scott_Matrix_XDK': ['Coffee',
#   'Dishes',
#   'Soap dispensed',
#   'Vacuum cleaning'],
#  'Left_Left_scott_scott_Mite_Matrix': ['Dishes', 'Blender running'],
#  'Left_Left_scott_scott_Mite_XDK': ['Coffee', 'Soap dispensed'],
#  'Left_Left_scott_scott_XDK_Matrix': ['Dishes', 'Blender running'],
#  'Left_Left_scott_scott_XDK_Mite': ['Chopping food',
#   'Conversation',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed',
#   'Alarm',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Vacuum cleaning'],
#  'Left_Right_scott_scott_Mite_Mite': ['Chopping food',
#   'Kettle',
#   'Knocking',
#   'Microwave',
#   'Soap dispensed'],
#  'Left_Sink_scott_robotics_Mite_Mite': ['Coffee',
#   'Kettle',
#   'Microwave',
#   'Microwave door closed'],
#  'Left_Sink_scott_synergy_Mite_Mite': ['Chopping food',
#   'Microwave',
#   'Microwave button press',
#   'Kettle',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Microwave done chime',
#   'Soap dispensed'],
#  'Left_Table_scott_synergy_Mite_Mite': ['Microwave button press', 'Microwave'],
#  'Pantry_Coffee_scott_robotics_Mite_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Knocking',
#   'Microwave'],
#  'Pantry_Coffee_scott_synergy_Mite_Mite': ['Chopping food',
#   'Dishes',
#   'Kettle',
#   'Microwave',
#   'Conversation',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Soap dispensed'],
#  'Pantry_Entrance_scott_robotics_Mite_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Kettle',
#   'Microwave'],
#  'Pantry_Left_scott_scott_Mite_Mite': ['Chopping food',
#   'Coffee',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed',
#   'Soap dispensed'],
#  'Pantry_Pantry_scott_scott_Matrix_Mite': ['Conversation',
#   'Dishes',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Cupboard door opened'],
#  'Pantry_Pantry_scott_scott_Matrix_XDK': ['Conversation', 'Dishes'],
#  'Pantry_Pantry_scott_scott_Mite_XDK': ['Conversation', 'Dishes'],
#  'Pantry_Pantry_scott_scott_XDK_Matrix': ['Vacuum cleaning'],
#  'Pantry_Pantry_scott_scott_XDK_Mite': ['Conversation',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Vacuum cleaning'],
#  'Pantry_Right_scott_scott_Mite_Mite': ['Chopping food',
#   'Kettle',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed',
#   'Soap dispensed'],
#  'Pantry_Sink_scott_robotics_Mite_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Kettle',
#   'Microwave',
#   'Microwave door closed'],
#  'Pantry_Sink_scott_synergy_Mite_Mite': ['Chopping food',
#   'Conversation',
#   'Microwave',
#   'Microwave button press',
#   'Kettle',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Microwave done chime',
#   'Soap dispensed'],
#  'Pantry_Table_scott_synergy_Mite_Mite': ['Chopping food',
#   'Conversation',
#   'Microwave',
#   'Microwave button press',
#   'Dishes'],
#  'Right_Coffee_scott_robotics_Mite_Mite': ['Coffee',
#   'Conversation',
#   'Kettle',
#   'Knocking',
#   'Microwave'],
#  'Right_Coffee_scott_synergy_Mite_Mite': ['Conversation',
#   'Kettle',
#   'Microwave',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Soap dispensed'],
#  'Right_Entrance_scott_robotics_Mite_Mite': ['Coffee',
#   'Conversation',
#   'Kettle',
#   'Microwave'],
#  'Right_Left_scott_scott_Mite_Mite': ['Coffee',
#   'Knocking',
#   'Microwave',
#   'Soap dispensed'],
#  'Right_Right_scott_scott_Matrix_Mite': ['Chopping food',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Soap dispensed',
#   'Vacuum cleaning'],
#  'Right_Right_scott_scott_Matrix_XDK': ['Dishes'],
#  'Right_Right_scott_scott_Mite_Matrix': ['Kettle', 'Alarm'],
#  'Right_Right_scott_scott_Mite_XDK': ['Blender running'],
#  'Right_Right_scott_scott_XDK_Matrix': ['Kettle',
#   'Alarm',
#   'Blender running',
#   'Vacuum cleaning'],
#  'Right_Right_scott_scott_XDK_Mite': ['Chopping food',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Soap dispensed'],
#  'Right_Sink_scott_robotics_Mite_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Kettle',
#   'Microwave'],
#  'Right_Sink_scott_synergy_Mite_Mite': ['Microwave button press',
#   'Conversation',
#   'Kettle',
#   'Microwave',
#   'Microwave door closed',
#   'Knocking',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Microwave done chime',
#   'Soap dispensed'],
#  'Right_Table_scott_synergy_Mite_Mite': ['Conversation',
#   'Microwave button press'],
#  'Sink_Coffee_robotics_robotics_Mite_Mite': ['Coffee', 'Knocking'],
#  'Sink_Coffee_robotics_synergy_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Conversation',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed'],
#  'Sink_Coffee_synergy_robotics_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Coffee',
#   'Knocking'],
#  'Sink_Coffee_synergy_synergy_Mite_Mite': ['Chopping food',
#   'Kettle',
#   'Conversation',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed',
#   'Soap dispensed'],
#  'Sink_Entrance_robotics_robotics_Mite_Mite': ['Microwave'],
#  'Sink_Entrance_synergy_robotics_Mite_Mite': ['Kettle', 'Microwave', 'Coffee'],
#  'Sink_Left_robotics_scott_Mite_Mite': ['Coffee',
#   'Conversation',
#   'Knocking',
#   'Microwave door closed'],
#  'Sink_Left_synergy_scott_Mite_Mite': ['Microwave',
#   'Dishes',
#   'Coffee',
#   'Knocking',
#   'Cupboard door opened',
#   'Soap dispensed',
#   'Microwave door closed',
#   'Cupboard door closed'],
#  'Sink_Pantry_synergy_scott_Mite_Mite': ['Cupboard door closed',
#   'Cupboard door opened'],
#  'Sink_Right_robotics_scott_Mite_Mite': ['Chopping food',
#   'Conversation',
#   'Kettle',
#   'Knocking',
#   'Microwave',
#   'Microwave door closed'],
#  'Sink_Right_synergy_scott_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door closed',
#   'Soap dispensed'],
#  'Sink_Sink_robotics_robotics_Matrix_Mite': ['Chopping food',
#   'Coffee',
#   'Conversation',
#   'Dishes',
#   'Kettle',
#   'Microwave door closed'],
#  'Sink_Sink_robotics_robotics_Matrix_XDK': ['Conversation', 'Microwave'],
#  'Sink_Sink_robotics_robotics_Mite_Matrix': ['Conversation',
#   'Dishes',
#   'Kettle',
#   'Microwave'],
#  'Sink_Sink_robotics_robotics_Mite_XDK': ['Microwave'],
#  'Sink_Sink_robotics_robotics_XDK_Matrix': ['Conversation',
#   'Dishes',
#   'Kettle'],
#  'Sink_Sink_robotics_robotics_XDK_Mite': ['Chopping food',
#   'Coffee',
#   'Kettle',
#   'Microwave',
#   'Microwave door closed'],
#  'Sink_Sink_robotics_synergy_Mite_Mite': ['Microwave button press',
#   'Kettle',
#   'Microwave',
#   'Knocking',
#   'Microwave door closed'],
#  'Sink_Sink_synergy_robotics_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Coffee',
#   'Microwave door closed'],
#  'Sink_Sink_synergy_synergy_Matrix_Mite': ['Chopping food',
#   'Conversation',
#   'Microwave',
#   'Microwave button press',
#   'Dishes',
#   'Kettle',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Knocking',
#   'Microwave done chime',
#   'Microwave door closed',
#   'Soap dispensed',
#   'Vacuum cleaning'],
#  'Sink_Sink_synergy_synergy_Matrix_XDK': ['Conversation',
#   'Dishes',
#   'Microwave',
#   'Blender running',
#   'Vacuum cleaning'],
#  'Sink_Sink_synergy_synergy_Mite_Matrix': ['Chopping food',
#   'Dishes',
#   'Conversation',
#   'Microwave',
#   'Alarm',
#   'Blender running'],
#  'Sink_Sink_synergy_synergy_Mite_Mite': ['Conversation',
#   'Kettle',
#   'Microwave button press',
#   'Cupboard door opened',
#   'Microwave done chime'],
#  'Sink_Sink_synergy_synergy_Mite_XDK': ['Conversation',
#   'Microwave',
#   'Blender running'],
#  'Sink_Sink_synergy_synergy_XDK_Matrix': ['Chopping food',
#   'Conversation',
#   'Dishes',
#   'Microwave',
#   'Alarm',
#   'Blender running',
#   'Vacuum cleaning'],
#  'Sink_Sink_synergy_synergy_XDK_Mite': ['Chopping food',
#   'Conversation',
#   'Microwave',
#   'Microwave button press',
#   'Kettle',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Cupboard door opened',
#   'Knocking',
#   'Microwave done chime',
#   'Microwave door closed',
#   'Soap dispensed',
#   'Vacuum cleaning'],
#  'Sink_Table_robotics_synergy_Mite_Mite': ['Conversation',
#   'Microwave button press'],
#  'Sink_Table_synergy_synergy_Mite_Mite': ['Chopping food',
#   'Microwave button press',
#   'Conversation'],
#  'Table_Coffee_synergy_robotics_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Chopping food',
#   'Conversation',
#   'Coffee',
#   'Knocking'],
#  'Table_Coffee_synergy_synergy_Mite_Mite': ['Conversation',
#   'Kettle',
#   'Chopping food',
#   'Coffee',
#   'Cupboard door opened',
#   'Knocking',
#   'Microwave door closed',
#   'Soap dispensed'],
#  'Table_Entrance_synergy_robotics_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Chopping food',
#   'Coffee'],
#  'Table_Left_synergy_scott_Mite_Mite': ['Microwave',
#   'Chopping food',
#   'Coffee',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Soap dispensed'],
#  'Table_Pantry_synergy_scott_Mite_Mite': ['Cupboard door opened'],
#  'Table_Right_synergy_scott_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Chopping food',
#   'Knocking',
#   'Microwave door closed',
#   'Cupboard door opened',
#   'Soap dispensed'],
#  'Table_Sink_synergy_robotics_Mite_Mite': ['Kettle',
#   'Microwave',
#   'Chopping food',
#   'Coffee',
#   'Microwave door closed'],
#  'Table_Sink_synergy_synergy_Mite_Mite': ['Conversation',
#   'Kettle',
#   'Chopping food',
#   'Cupboard door opened',
#   'Knocking',
#   'Microwave done chime',
#   'Microwave door closed',
#   'Soap dispensed'],
#  'Table_Table_synergy_synergy_Matrix_Mite': ['Chopping food',
#   'Dishes',
#   'Microwave',
#   'Microwave button press',
#   'Conversation',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed',
#   'Vacuum cleaning'],
#  'Table_Table_synergy_synergy_Matrix_XDK': ['Conversation', 'Dishes'],
#  'Table_Table_synergy_synergy_Mite_Matrix': ['Conversation',
#   'Microwave',
#   'Alarm',
#   'Blender running'],
#  'Table_Table_synergy_synergy_Mite_Mite': ['Conversation', 'Chopping food'],
#  'Table_Table_synergy_synergy_Mite_XDK': ['Conversation', 'Dishes'],
#  'Table_Table_synergy_synergy_XDK_Matrix': ['Conversation',
#   'Microwave',
#   'Alarm',
#   'Blender running'],
#  'Table_Table_synergy_synergy_XDK_Mite': ['Chopping food',
#   'Microwave',
#   'Microwave button press',
#   'Conversation',
#   'Dishes',
#   'Alarm',
#   'Blender running',
#   'Cupboard door closed']}

# %%
activity_ids_to_retrain = {}
for transfer, activities in activities_to_retrain.items():
    activity_ids = [configuration['activities'].index(a) for a in activities]
    activity_ids_to_retrain[transfer] = activity_ids

output = open('activity_ids_to_retrain.p', 'wb')
pickle.dump(activity_ids_to_retrain, output)
output.close()

# %%
tflscripts.set_dataset_folder('../../datasets/')

def map_result(result):
    stats = tflscripts.TestResultStatistics(result, configuration)
    
    transfer_key = build_transfer_key(source_placement=stats.source_placement(),
                                      target_placement=stats.target_placement(),
                                      source_room=stats.source_room(),
                                      target_room=stats.target_room(),
                                      source_device_type=stats.source_device_type(),
                                      target_device_type=stats.target_device_type())
    
    if transfer_key in activity_ids_to_retrain:
        activities_i = activity_ids_to_retrain[transfer_key]
        specificity = stats.specificity_with_additional_activities(activities_i)
        return [
            result.source_dataset,
            result.target_dataset,
            stats.source_device(),
            stats.target_device(),
            stats.type_of_transfer(),
            stats.classifier_name(),
            result.label_name(),
            stats.features_name(),
            len(activities_i),
            specificity
        ]

    return None

def read_dataset_device(dataset, device):
    test_set = tflscripts.TestSet(name='_'.join([dataset, device]))

    if test_set.exists():
        results = test_set.map_results(map_result)
        return results
    else:
        return []

all_rows = []
for dataset in configuration['device_roles']:
    print(dataset)
    for device in configuration['device_roles'][dataset]:
        print(device)
        rows = read_dataset_device(dataset, device)
        all_rows += rows

columns = [
    'source_dataset',
    'target_dataset',
    'source_device',
    'target_device',
    'type_of_transfer',
    'classifier',
    'label',
    'features_name',
    'num_activities_for_specificity',
    'specificity_for_retrained'
]

specificity_results = pd.DataFrame([r for r in all_rows if r != None])
specificity_results.columns = columns
# Out:
# scott-final-iter2
# TI SensorTag 85
# Matrix b827ebe6e0f8
# xdk_3
# Matrix b827eb96f31a
# TI SensorTag 604
# DialogIoT 591844599
# xdk_1
# 128.237.247.134
# 128.237.246.127
# DialogIoT 591844765
# xdk_2
# TI SensorTag 690
# DialogIoT 591844595
# 128.237.248.186
# Matrix b827eb41f96f
# synergy-final-iter3
# 128.237.239.234
# TI SensorTag 709
# Matrix b827ebe6e0f8
# 128.237.234.0
# Matrix b827eb96f31a
# DialogIoT 591844595
# DialogIoT 591844599
# TI SensorTag 33
# xdk_2
# xdk_3
# DialogIoT 591844765
# xdk_1
# TI SensorTag 535
# Matrix b827eb41f96f
# 128.237.237.122
# robotics-final
# TI SensorTag 85
# Matrix b827ebe6e0f8
# xdk_3
# Matrix b827eb96f31a
# TI SensorTag 604
# DialogIoT 591844599
# xdk_1
# 128.237.247.134
# 128.237.246.127
# DialogIoT 591844765
# xdk_2
# TI SensorTag 690
# DialogIoT 591844595
# 128.237.248.186
# Matrix b827eb41f96f
# synergy-final-iter5
# 128.237.247.190
# xdk_3
# Matrix b827ebe6e0f8
# 128.237.227.76
# Matrix b827eb96f31a
# 128.237.250.218
# Matrix b827eb41f96f
# xdk_1
# xdk_2
# synergy-mites-colocated
# 128.237.246.127
# 128.237.253.157
# 128.237.248.186
# 128.237.242.0
# synergy-mites-kitchen
# 128.237.246.127
# 128.237.253.157
# 128.237.248.186
# 128.237.242.0
# synergy-final-iter2
# 128.237.254.195
# TI SensorTag 85
# Matrix b827ebe6e0f8
# xdk_3
# Matrix b827eb96f31a
# TI SensorTag 604
# DialogIoT 591844599
# xdk_1
# xdk_2
# 128.237.246.127
# DialogIoT 591844765
# TI SensorTag 690
# DialogIoT 591844595
# 128.237.248.186
# Matrix b827eb41f96f
# synergy-final-iter4
# 128.237.247.190
# xdk_3
# Matrix b827ebe6e0f8
# 128.237.227.76
# Matrix b827eb96f31a
# 128.237.250.218
# Matrix b827eb41f96f
# xdk_1
# xdk_2
# synergy-final-iter1
# 128.237.254.195
# TI SensorTag 85
# Matrix b827ebe6e0f8
# xdk_3
# Matrix b827eb96f31a
# TI SensorTag 604
# DialogIoT 591844599
# xdk_1
# xdk_2
# 128.237.246.127
# DialogIoT 591844765
# TI SensorTag 690
# DialogIoT 591844595
# 128.237.248.186
# Matrix b827eb41f96f
# scott-final-iter3
# 128.237.247.190
# xdk_3
# Matrix b827ebe6e0f8
# 128.237.227.76
# Matrix b827eb96f31a
# 128.237.250.218
# Matrix b827eb41f96f
# xdk_1
# xdk_2
# scott-final-iter1
# TI SensorTag 85
# Matrix b827ebe6e0f8
# xdk_3
# Matrix b827eb96f31a
# TI SensorTag 604
# DialogIoT 591844599
# xdk_1
# 128.237.247.134
# 128.237.246.127
# DialogIoT 591844765
# xdk_2
# TI SensorTag 690
# DialogIoT 591844595
# 128.237.248.186
# Matrix b827eb41f96f

# %%
specificity_results = specificity_results.groupby([
    'source_dataset',
    'target_dataset',
    'source_device',
    'target_device',
    'type_of_transfer',
    'classifier',
    'label',
    'features_name',
    'num_activities_for_specificity'
])[
    'specificity_for_retrained'
].mean().reset_index()

# %%
df = pd.merge(df,
        specificity_results,
        how='left',
        on=['source_dataset', 'target_dataset', 'source_device', 'target_device', 'type_of_transfer', 'classifier', 'label', 'features_name'])

# %%
specificity_results
# Out:
#             source_dataset       target_dataset source_device target_device  \
# 0           robotics-final       robotics-final      Matrix 1        Mite 4
# 1           robotics-final       robotics-final      Matrix 1        Mite 4
# 2           robotics-final       robotics-final      Matrix 1        Mite 4
# 3           robotics-final       robotics-final      Matrix 1        Mite 4
# 4           robotics-final       robotics-final      Matrix 1        Mite 4
# 5           robotics-final       robotics-final      Matrix 1        Mite 4
# 6           robotics-final       robotics-final      Matrix 1        Mite 4
# 7           robotics-final       robotics-final      Matrix 1        Mite 4
# 8           robotics-final       robotics-final      Matrix 1        Mite 4
# 9           robotics-final       robotics-final      Matrix 1        Mite 4
# 10          robotics-final       robotics-final      Matrix 1        Mite 4
# 11          robotics-final       robotics-final      Matrix 1        Mite 4
# 12          robotics-final       robotics-final      Matrix 1        Mite 4
# 13          robotics-final       robotics-final      Matrix 1        Mite 4
# 14          robotics-final       robotics-final      Matrix 1        Mite 4
# 15          robotics-final       robotics-final      Matrix 1        Mite 4
# 16          robotics-final       robotics-final      Matrix 1        Mite 4
# 17          robotics-final       robotics-final      Matrix 1        Mite 4
# 18          robotics-final       robotics-final      Matrix 1        Mite 4
# 19          robotics-final       robotics-final      Matrix 1        Mite 4
# 20          robotics-final       robotics-final      Matrix 1        Mite 4
# 21          robotics-final       robotics-final      Matrix 1        Mite 4
# 22          robotics-final       robotics-final      Matrix 1        Mite 4
# 23          robotics-final       robotics-final      Matrix 1        Mite 4
# 24          robotics-final       robotics-final      Matrix 1        Mite 4
# 25          robotics-final       robotics-final      Matrix 1        Mite 4
# 26          robotics-final       robotics-final      Matrix 1        Mite 4
# 27          robotics-final       robotics-final      Matrix 1        Mite 4
# 28          robotics-final       robotics-final      Matrix 1        Mite 4
# 29          robotics-final       robotics-final      Matrix 1        Mite 4
# ...                    ...                  ...           ...           ...
# 89460  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89461  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89462  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89463  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89464  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89465  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89466  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89467  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89468  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89469  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89470  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89471  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89472  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89473  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89474  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89475  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89476  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89477  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89478  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89479  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89480  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89481  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89482  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89483  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89484  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89485  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89486  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89487  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89488  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
# 89489  synergy-final-iter5  synergy-final-iter5         XDK 3        Mite 4
#
#                      type_of_transfer          classifier  \
# 0      Different device in same place  LogisticRegression
# 1      Different device in same place  LogisticRegression
# 2      Different device in same place  LogisticRegression
# 3      Different device in same place  LogisticRegression
# 4      Different device in same place  LogisticRegression
# 5      Different device in same place  LogisticRegression
# 6      Different device in same place  LogisticRegression
# 7      Different device in same place  LogisticRegression
# 8      Different device in same place  LogisticRegression
# 9      Different device in same place  LogisticRegression
# 10     Different device in same place  LogisticRegression
# 11     Different device in same place  LogisticRegression
# 12     Different device in same place  LogisticRegression
# 13     Different device in same place  LogisticRegression
# 14     Different device in same place  LogisticRegression
# 15     Different device in same place  LogisticRegression
# 16     Different device in same place  LogisticRegression
# 17     Different device in same place  LogisticRegression
# 18     Different device in same place  LogisticRegression
# 19     Different device in same place  LogisticRegression
# 20     Different device in same place  LogisticRegression
# 21     Different device in same place  LogisticRegression
# 22     Different device in same place  LogisticRegression
# 23     Different device in same place  LogisticRegression
# 24     Different device in same place  LogisticRegression
# 25     Different device in same place  LogisticRegression
# 26     Different device in same place  LogisticRegression
# 27     Different device in same place  LogisticRegression
# 28     Different device in same place  LogisticRegression
# 29     Different device in same place  LogisticRegression
# ...                               ...                 ...
# 89460  Different device in same place                 SVM
# 89461  Different device in same place                 SVM
# 89462  Different device in same place                 SVM
# 89463  Different device in same place                 SVM
# 89464  Different device in same place                 SVM
# 89465  Different device in same place                 SVM
# 89466  Different device in same place                 SVM
# 89467  Different device in same place                 SVM
# 89468  Different device in same place                 SVM
# 89469  Different device in same place                 SVM
# 89470  Different device in same place                 SVM
# 89471  Different device in same place                 SVM
# 89472  Different device in same place                 SVM
# 89473  Different device in same place                 SVM
# 89474  Different device in same place                 SVM
# 89475  Different device in same place                 SVM
# 89476  Different device in same place                 SVM
# 89477  Different device in same place                 SVM
# 89478  Different device in same place                 SVM
# 89479  Different device in same place                 SVM
# 89480  Different device in same place                 SVM
# 89481  Different device in same place                 SVM
# 89482  Different device in same place                 SVM
# 89483  Different device in same place                 SVM
# 89484  Different device in same place                 SVM
# 89485  Different device in same place                 SVM
# 89486  Different device in same place                 SVM
# 89487  Different device in same place                 SVM
# 89488  Different device in same place                 SVM
# 89489  Different device in same place                 SVM
#
#                        label                 features_name  \
# 0              Chopping food  Accelerometer & magnetometer
# 1              Chopping food                           All
# 2              Chopping food                 Environmental
# 3              Chopping food                    Microphone
# 4              Chopping food    Microphone & accelerometer
# 5                     Coffee  Accelerometer & magnetometer
# 6                     Coffee                           All
# 7                     Coffee                 Environmental
# 8                     Coffee                    Microphone
# 9                     Coffee    Microphone & accelerometer
# 10              Conversation  Accelerometer & magnetometer
# 11              Conversation                           All
# 12              Conversation                 Environmental
# 13              Conversation                    Microphone
# 14              Conversation    Microphone & accelerometer
# 15                    Dishes  Accelerometer & magnetometer
# 16                    Dishes                           All
# 17                    Dishes                 Environmental
# 18                    Dishes                    Microphone
# 19                    Dishes    Microphone & accelerometer
# 20                    Kettle  Accelerometer & magnetometer
# 21                    Kettle                           All
# 22                    Kettle                 Environmental
# 23                    Kettle                    Microphone
# 24                    Kettle    Microphone & accelerometer
# 25                  Knocking  Accelerometer & magnetometer
# 26                  Knocking                           All
# 27                  Knocking                 Environmental
# 28                  Knocking                    Microphone
# 29                  Knocking    Microphone & accelerometer
# ...                      ...                           ...
# 89460   Cupboard door opened  Accelerometer & magnetometer
# 89461   Cupboard door opened                           All
# 89462   Cupboard door opened                 Environmental
# 89463   Cupboard door opened                    Microphone
# 89464   Cupboard door opened    Microphone & accelerometer
# 89465               Knocking  Accelerometer & magnetometer
# 89466               Knocking                           All
# 89467               Knocking                 Environmental
# 89468               Knocking                    Microphone
# 89469               Knocking    Microphone & accelerometer
# 89470   Microwave done chime  Accelerometer & magnetometer
# 89471   Microwave done chime                           All
# 89472   Microwave done chime                 Environmental
# 89473   Microwave done chime                    Microphone
# 89474   Microwave done chime    Microphone & accelerometer
# 89475  Microwave door closed  Accelerometer & magnetometer
# 89476  Microwave door closed                           All
# 89477  Microwave door closed                 Environmental
# 89478  Microwave door closed                    Microphone
# 89479  Microwave door closed    Microphone & accelerometer
# 89480         Soap dispensed  Accelerometer & magnetometer
# 89481         Soap dispensed                           All
# 89482         Soap dispensed                 Environmental
# 89483         Soap dispensed                    Microphone
# 89484         Soap dispensed    Microphone & accelerometer
# 89485        Vacuum cleaning  Accelerometer & magnetometer
# 89486        Vacuum cleaning                           All
# 89487        Vacuum cleaning                 Environmental
# 89488        Vacuum cleaning                    Microphone
# 89489        Vacuum cleaning    Microphone & accelerometer
#
#        num_activities_for_specificity  specificity_for_retrained
# 0                                   6                   0.620690
# 1                                   6                   0.814599
# 2                                   6                   0.834751
# 3                                   6                   0.850873
# 4                                   6                   0.865652
# 5                                   6                   0.776982
# 6                                   6                   0.748321
# 7                                   6                   0.839230
# 8                                   6                   0.698612
# 9                                   6                   0.773847
# 10                                  6                   0.600985
# 11                                  6                   0.696820
# 12                                  6                   0.931930
# 13                                  6                   0.714286
# 14                                  6                   0.729512
# 15                                  6                   0.628751
# 16                                  6                   0.639498
# 17                                  6                   0.832064
# 18                                  6                   0.724586
# 19                                  6                   0.710703
# 20                                  6                   0.678012
# 21                                  6                   0.729512
# 22                                  6                   0.775190
# 23                                  6                   0.733990
# 24                                  6                   0.738021
# 25                                  6                   0.944021
# 26                                  6                   0.926108
# 27                                  6                   0.991939
# 28                                  6                   0.983878
# 29                                  6                   0.981639
# ...                               ...                        ...
# 89460                              14                   0.976854
# 89461                              14                   0.983523
# 89462                              14                   0.990977
# 89463                              14                   0.963907
# 89464                              14                   0.981169
# 89465                              14                   0.974500
# 89466                              14                   0.987838
# 89467                              14                   0.983915
# 89468                              14                   0.986661
# 89469                              14                   0.978423
# 89470                              14                   0.986269
# 89471                              14                   0.987054
# 89472                              14                   0.983915
# 89473                              14                   0.973715
# 89474                              14                   0.983131
# 89475                              14                   0.990585
# 89476                              14                   0.992154
# 89477                              14                   0.991369
# 89478                              14                   0.931346
# 89479                              14                   0.990977
# 89480                              14                   0.985092
# 89481                              14                   0.987054
# 89482                              14                   0.982738
# 89483                              14                   0.900353
# 89484                              14                   0.985877
# 89485                              14                   0.764221
# 89486                              14                   0.840330
# 89487                              14                   0.837583
# 89488                              14                   0.846999
# 89489                              14                   0.838760
#
# [89490 rows x 10 columns]

# %%
df.to_pickle('results_retrained_specificity.p')

# %%
df.loc[df.type_of_transfer == 'Same device in same place']
# Out:
#             source_dataset       target_dataset source_device_id  \
# 47451  synergy-final-iter4  synergy-final-iter5  128.237.247.190
# 
# 47480   Table_synergy_Mite 1_Cupboard door opened
# ...                                           ...
# 54027               Table_synergy_Mite 1_Knocking
# 54028               Table_synergy_Mite 1_Knocking
# 54029               Table_synergy_Mite 1_Knocking
# 54030               Table_synergy_Mite 1_Knocking
# 54031               Table_synergy_Mite 1_Knocking
# 54032               Table_synergy_Mite 1_Knocking
# 54033   Table_synergy_Mite 1_Microwave done chime
# 54034   Table_synergy_Mite 1_Microwave done chime
# 54035   Table_synergy_Mite 1_Microwave done chime
# 54036   Table_synergy_Mite 1_Microwave done chime
# 54037   Table_synergy_Mite 1_Microwave done chime
# 54038   Table_synergy_Mite 1_Microwave done chime
# 54039  Table_synergy_Mite 1_Microwave door closed
# 54040  Table_synergy_Mite 1_Microwave door closed
# 54041  Table_synergy_Mite 1_Microwave door closed
# 54042  Table_synergy_Mite 1_Microwave door closed
# 54043  Table_synergy_Mite 1_Microwave door closed
# 54044  Table_synergy_Mite 1_Microwave door closed
# 54045         Table_synergy_Mite 1_Soap dispensed
# 54046         Table_synergy_Mite 1_Soap dispensed
# 54047         Table_synergy_Mite 1_Soap dispensed
# 54048         Table_synergy_Mite 1_Soap dispensed
# 54049         Table_synergy_Mite 1_Soap dispensed
# 54050         Table_synergy_Mite 1_Soap dispensed
# 54051        Table_synergy_Mite 1_Vacuum cleaning
# 54052        Table_synergy_Mite 1_Vacuum cleaning
# 54053        Table_synergy_Mite 1_Vacuum cleaning
# 54054        Table_synergy_Mite 1_Vacuum cleaning
# 54055        Table_synergy_Mite 1_Vacuum cleaning
# 54056        Table_synergy_Mite 1_Vacuum cleaning
#
#                                  transfer_with_label_key  \
# 47451        Table_Table_synergy_synergy_Mite_Mite_Alarm
# 47452        Table_Table_synergy_synergy_Mite_Mite_Alarm
# 47453        Table_Table_synergy_synergy_Mite_Mite_Alarm
# 47454        Table_Table_synergy_synergy_Mite_Mite_Alarm
# 47455        Table_Table_synergy_synergy_Mite_Mite_Alarm
# 47456        Table_Table_synergy_synergy_Mite_Mite_Alarm
# 47457  Table_Table_synergy_synergy_Mite_Mite_Blender ...
# 47458  Table_Table_synergy_synergy_Mite_Mite_Blender ...
# 47459  Table_Table_synergy_synergy_Mite_Mite_Blender ...
# 47460  Table_Table_synergy_synergy_Mite_Mite_Blender ...
# 47461  Table_Table_synergy_synergy_Mite_Mite_Blender ...
# 47462  Table_Table_synergy_synergy_Mite_Mite_Blender ...
# 47463       Table_Table_synergy_synergy_Mite_Mite_Coffee
# 47464       Table_Table_synergy_synergy_Mite_Mite_Coffee
# 47465       Table_Table_synergy_synergy_Mite_Mite_Coffee
# 47466       Table_Table_synergy_synergy_Mite_Mite_Coffee
# 47467       Table_Table_synergy_synergy_Mite_Mite_Coffee
# 47468       Table_Table_synergy_synergy_Mite_Mite_Coffee
# 47469  Table_Table_synergy_synergy_Mite_Mite_Cupboard...
# 47470  Table_Table_synergy_synergy_Mite_Mite_Cupboard...
# 47471  Table_Table_synergy_synergy_Mite_Mite_Cupboard...
# 47472  Table_Table_synergy_synergy_Mite_Mite_Cupboard...
Table_Table_synergy_synergy_Mite_Mite                1.0
# 47474  Table_Table_synergy_synergy_Mite_Mite                1.0
# 47475  Table_Table_synergy_synergy_Mite_Mite                0.0
# 47476  Table_Table_synergy_synergy_Mite_Mite                0.0
# 47477  Table_Table_synergy_synergy_Mite_Mite                0.0
# 47478  Table_Table_synergy_synergy_Mite_Mite                0.0
# 47479  Table_Table_synergy_synergy_Mite_Mite                0.0
# 47480  Table_Table_synergy_synergy_Mite_Mite                0.0
# ...                                      ...                ...
# 54027  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54028  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54029  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54030  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54031  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54032  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54033  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54034  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54035  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54036  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54037  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54038  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54039  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54040  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54041  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54042  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54043  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54044  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54045  Table_Table_synergy_synergy_Mite_Mite                0.0
# 54046  Table_Table_synergy_synergy_Mite_Mite                0.0
# 54047  Table_Table_synergy_synergy_Mite_Mite                0.0
# 54048  Table_Table_synergy_synergy_Mite_Mite                0.0
# 54049  Table_Table_synergy_synergy_Mite_Mite                0.0
# 54050  Table_Table_synergy_synergy_Mite_Mite                0.0
# 54051  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54052  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54053  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54054  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54055  Table_Table_synergy_synergy_Mite_Mite                1.0
# 54056  Table_Table_synergy_synergy_Mite_Mite                1.0
#
#       num_activities_for_specificity specificity_for_retrained
# 47451                            2.0                  0.997323
# 47452                            2.0                  0.986613
# 47453                            2.0                  0.488621
# 47454                            2.0                  1.000000
# 47455                            2.0                  0.997323
# 47456                            2.0                  0.966533
# 47457                            2.0                  0.991968
# 47458                            2.0                  0.950469
# 47459                            2.0                  0.875502
# 47460                            2.0                  0.990629
# 47461                            2.0                  0.995984
# 47462                            2.0                  0.962517
# 47463                            2.0                  0.906292
# 47464                            2.0                  0.832664
# 47465                            2.0                  0.540830
# 47466                            2.0                  0.752343
# 47467                            2.0                  0.847390
# 47468                            2.0                  0.986613
# 47469                            2.0                  0.998661
# 47470                            2.0                  0.997323
# 47471                            2.0                  0.997323
# 47472                            2.0                  0.995984
# 47473                            2.0                  0.998661
# 47474                            2.0                  1.000000
# 47475                            2.0                  0.994645
# 47476                            2.0                  0.997323
# 47477                            2.0                  0.997323
# 47478                            2.0                  1.000000
# 47479                            2.0                  0.997323
# 47480                            2.0                  1.000000
# ...                              ...                       ...
# 54027                            2.0                  0.996047
# 54028                            2.0                  0.958498
# 54029                            2.0                  0.994071
# 54030                            2.0                  0.999012
# 54031                            2.0                  0.995059
# 54032                            2.0                  0.999012
# 54033                            2.0                  1.000000
# 54034                            2.0                  0.688735
# 54035                            2.0                  0.986166
# 54036                            2.0                  1.000000
# 54037                            2.0                  0.994071
# 54038                            2.0                  1.000000
# 54039                            2.0                  1.000000
# 54040                            2.0                  1.000000
# 54041                            2.0                  0.993083
# 54042                            2.0                  1.000000
# 54043                            2.0                  1.000000
# 54044                            2.0                  0.986166
# 54045                            2.0                  0.999012
# 54046                            2.0                  0.987154
# 54047                            2.0                  0.991107
# 54048                            2.0                  0.996047
# 54049                            2.0                  0.998024
# 54050                            2.0                  1.000000
# 54051                            2.0                  1.000000
# 54052                            2.0                  0.771739
# 54053                            2.0                  0.765810
# 54054                            2.0                  1.000000
# 54055                            2.0                  1.000000
# 54056                            2.0                  0.958498
#
# [360 rows x 55 columns]
